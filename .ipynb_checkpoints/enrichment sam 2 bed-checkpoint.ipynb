# %%
import os
import time
import json
import numpy as np
from functools import reduce
import re
from collections import Counter
from intervaltree import Interval, IntervalTree

# %%
nts = 'AGNCT'
pairs = {nts[i]:nts[4-i] for i in range(5)}
def revComp(seq):
    return ''.join([pairs[nt] for nt in seq][::-1])

# %%
def getTranscriptGeneName(name):
    match = re.search(r'(:|=)((\w+[A-Z]\w+\.t?\d+)|([A-Z]\w+\.t?\d+))((\.\d+)|([a-z](\.\d+)*))*(;|$)', name)
    if match:
        return match.group(2)
    return '-'


def getAlias(name):
    match = re.search(r'(Alias=)([\w\-.]+)', name)
    if match:
        return match.group(2)
    return '-'


def getBiotype(name):
    match = re.search(r'(biotype=)([\w\-]+);?', name)
    if match:
        return match.group(2)
    return '-'

def getWBGene(name):
    match = re.search(r'(WBGene\d+);?', name)
    if match:
        return match.group(1)
    return '-'


def parseWormbaseExon(data):
    avoid = {'intron', 'gene', 'mRNA'}
    gene2ivs = {}
    gene2info = {}
    seen = {}
    for curr in data:
        metadata = curr[-1]
        gene = getTranscriptGeneName(metadata)
            
        if gene not in gene2info:
            gene2info[gene] = {'chrom':curr[0], 'strand':curr[6], 'element':set([curr[2]])}
            
        else:
            gene2info[gene]['element'].add(curr[2])
        
        if 'Alias=' in metadata:
            alias = getAlias(metadata)
            if 'alias' not in gene2info[gene]:
                gene2info[gene]['alias'] = set([alias])
            else:
                gene2info[gene]['alias'].add(alias)
        if 'biotype=' in metadata:
            biotype = getBiotype(metadata)
            gene2info[gene]['biotype'] = biotype
        if 'WBGene' in metadata:
            wbgene = getWBGene(metadata)
            if 'wbgene' in gene2info[gene]:
                gene2info[gene]['wbgene'].add(wbgene)                    
            else:
                gene2info[gene]['wbgene'] = set([wbgene])
                
                
        if gene in gene2ivs:
            if curr[2] not in avoid:
                gene2ivs[gene].append((int(curr[3])-1, int(curr[4])))
        else:
            if curr[2] not in avoid:
                gene2ivs[gene] = [(int(curr[3])-1, int(curr[4]))]
                   
            
    sub_elements = {'CDS', 'exon', 'five_prime_UTR', 'three_prime_UTR', 'nc_primary_transcript', 'pre_miRNA', 'miRNA_primary_transcript'}
    for curr in gene2info:
        if 'biotype' not in gene2info[curr]:
            diff = gene2info[curr]['element'] - sub_elements
            if isinstance(diff, str):
                gene2info[curr]['biotype'] = diff
            else:
                gene2info[curr]['biotype'] = ','.join(list(diff))
        
        if 'alias' not in gene2info[curr]:
            gene2info[curr]['alias'] = curr
        else:
            gene2info[curr]['alias'] = ','.join(list(gene2info[curr]['alias']))
            
        if 'wbgene' in gene2info[curr]:
            gene2info[curr]['wbgene'] = ','.join(list(gene2info[curr]['wbgene']))
        
            
    return gene2ivs, gene2info

# %%
def getWormbaseData(file):
    with open(file) as f:
        data = [row.strip().split("\t") for row in f.readlines()]
    return data

def getMergedSequence(interval, info, id2seq):
    merged_seq = ''
    for curr in interval:
        start, end, _ = curr
        merged_seq += id2seq[info['chrom']][start:end]
    return merged_seq if info['strand'] == '+' else revComp(merged_seq)

    
def getMetaGenome(file): 
    data = getWormbaseData(file)
    gene2ivs, gene2info = parseWormbaseExon(data)

    gene2intervals = {}
    for gene in gene2ivs:
        curr = IntervalTree.from_tuples(gene2ivs[gene])
        curr.merge_overlaps()
        gene2info[gene]['interval'] = curr
        #gene2intervals[gene] = curr

        gene2info[gene]['start'] = curr.begin()
        gene2info[gene]['end'] = curr.end()
        
    
    return gene2info

# %%
file = 'ws268.wormbase'

# %%
gene2info= getMetaGenome(file)

# %%
[curr for curr in gene2info if 'wbgene' not in gene2info[curr]]
# Out:
# []

# %%
gene2info['Y105E8A.7']
# Out:
# {'alias': 'lev-10,eat-18',
#  'biotype': 'protein_coding',
#  'chrom': 'I',
#  'element': {'CDS',
#   'exon',
#   'five_prime_UTR',
#   'gene',
#   'mRNA',
#   'three_prime_UTR'},
#  'end': 14400222,
#  'interval': IntervalTree([Interval(14390332, 14390458), Interval(14391959, 14392203), Interval(14393324, 14393449), Interval(14393546, 14393629), Interval(14393757, 14393969), Interval(14395101, 14395309), Interval(14395359, 14395521), Interval(14396345, 14396496), Interval(14396539, 14396664), Interval(14396716, 14397098), Interval(14397611, 14397942), Interval(14398317, 14398857), Interval(14399417, 14399536), Interval(14399622, 14399839), Interval(14400057, 14400222)]),
#  'start': 14390332,
#  'strand': '+',
#  'wbgene': 'WBGene00001147,WBGene00002977'}

# %%
len(gene2info)
# Out:
# 46910

# %%
[(curr, gene2info[curr]) for curr in gene2info if 'alias' not in gene2info[curr]]

# %%
Counter([gene2info[curr]['biotype'] for curr in gene2info ])

# %%
len(gene2intervals)

# %%
[(curr, gene2info[curr]['wbgene']) for curr in gene2info if gene2info[curr]['alias'] == 'lev-10']

# %%
[(curr, gene2info[curr]['wbgene']) for curr in gene2info if ',' in gene2info[curr]['wbgene']]

# %%
gene2info['Y105E8A.7']

# %%
[(curr,gene2info[curr]) for curr in gene2info if gene2info[curr]['biotype']=='mRNA']

# %%
len(gene2info)

# %%
gene2info
# Out:
# {'Y74C9A.6': {'alias': 'Y74C9A.6',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 3909,
#   'interval': IntervalTree([Interval(3746, 3909)]),
#   'start': 3746,
#   'strand': '-',
#   'wbgene': 'WBGene00023193'},
#  'Y74C9A.3': {'alias': 'homt-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 10230,
#   'interval': IntervalTree([Interval(4115, 4358), Interval(5194, 5296), Interval(6036, 6327), Interval(9726, 9846), Interval(10094, 10230)]),
#   'start': 4115,
#   'strand': '-',
#   'wbgene': 'WBGene00022277'},
#  'Y74C9A.2': {'alias': 'nlp-40',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 16837,
#   'interval': IntervalTree([Interval(11494, 11561), Interval(11617, 11689), Interval(14949, 15160), Interval(16472, 16837)]),
#   'start': 11494,
#   'strand': '+',
#   'wbgene': 'WBGene00022276'},
#  'Y74C9A.4': {'alias': 'rcor-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 26781,
#   'interval': IntervalTree([Interval(17486, 17958), Interval(18005, 18115), Interval(19014, 19241), Interval(20270, 20478), Interval(20847, 20964), Interval(21012, 21139), Interval(24650, 24845), Interval(24928, 25090), Interval(25272, 25472), Interval(26370, 26524), Interval(26589, 26690), Interval(26732, 26781)]),
#   'start': 17486,
#   'strand': '-',
#   'wbgene': 'WBGene00022278'},
#  'Y74C9A.9': {'alias': 'Y74C9A.9',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 23600,
#   'interval': IntervalTree([Interval(22881, 23600)]),
#   'start': 22881,
#   'strand': '-',
#   'wbgene': 'WBGene00235381'},
#  'Y74C9A.5': {'alias': 'sesn-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 32544,
#   'interval': IntervalTree([Interval(27590, 28405), Interval(29099, 29367), Interval(29768, 30424), Interval(31768, 32072), Interval(32411, 32544)]),
#   'start': 27590,
#   'strand': '-',
#   'wbgene': 'WBGene00022279'},
#  'Y74C9A.7': {'alias': '21ur-15479',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 31543,
#   'interval': IntervalTree([Interval(31522, 31543)]),
#   'start': 31522,
#   'strand': '+',
#   'wbgene': 'WBGene00170953'},
#  'Y74C9A.8': {'alias': '21ur-13439',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 32435,
#   'interval': IntervalTree([Interval(32414, 32435)]),
#   'start': 32414,
#   'strand': '+',
#   'wbgene': 'WBGene00173569'},
#  'Y74C9A.1': {'alias': 'Y74C9A.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 44677,
#   'interval': IntervalTree([Interval(43732, 43961), Interval(44029, 44234), Interval(44280, 44324), Interval(44371, 44468), Interval(44520, 44677)]),
#   'start': 43732,
#   'strand': '+',
#   'wbgene': 'WBGene00022275'},
#  'Y48G1C.12': {'alias': 'Y48G1C.12',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 49857,
#   'interval': IntervalTree([Interval(47466, 47610), Interval(47695, 47858), Interval(48347, 48530), Interval(49250, 49857)]),
#   'start': 47466,
#   'strand': '+',
#   'wbgene': 'WBGene00044345'},
#  'Y48G1C.4': {'alias': 'pgs-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 54426,
#   'interval': IntervalTree([Interval(49918, 50016), Interval(50814, 51030), Interval(52282, 52410), Interval(52465, 52572), Interval(53265, 53337), Interval(53390, 53695), Interval(53943, 54426)]),
#   'start': 49918,
#   'strand': '+',
#   'wbgene': 'WBGene00021677'},
#  'Y48G1C.5': {'alias': 'Y48G1C.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 64066,
#   'interval': IntervalTree([Interval(55292, 55450), Interval(55889, 56047), Interval(56123, 56293), Interval(56536, 56687), Interval(56871, 57053), Interval(57256, 57625), Interval(59044, 60236), Interval(61235, 62051), Interval(62773, 62974), Interval(63796, 63856), Interval(63903, 63972), Interval(64017, 64066)]),
#   'start': 55292,
#   'strand': '-',
#   'wbgene': 'WBGene00021678'},
#  'Y48G1C.2': {'alias': 'csk-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 81071,
#   'interval': IntervalTree([Interval(71424, 71511), Interval(71844, 71932), Interval(72510, 72590), Interval(72646, 72897), Interval(72940, 73017), Interval(73604, 73766), Interval(74624, 74808), Interval(75170, 75490), Interval(75950, 76112), Interval(76948, 77153), Interval(77712, 77799), Interval(79312, 79447), Interval(80305, 81071)]),
#   'start': 71424,
#   'strand': '+',
#   'wbgene': 'WBGene00000812'},
#  'Y48G1C.10': {'alias': 'Y48G1C.10',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 91020,
#   'interval': IntervalTree([Interval(81192, 81272), Interval(81884, 81963), Interval(82015, 82137), Interval(82585, 82676), Interval(83180, 83420), Interval(84189, 84313), Interval(84387, 84567), Interval(84613, 84738), Interval(84835, 84985), Interval(86823, 86904), Interval(87033, 87223), Interval(87519, 87734), Interval(88267, 88500), Interval(88565, 88706), Interval(89371, 89584), Interval(90418, 90957), Interval(90967, 91020)]),
#   'start': 81192,
#   'strand': '+',
#   'wbgene': 'WBGene00021683'},
#  'Y48G1C.6': {'alias': 'Y48G1C.6',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 86293,
#   'interval': IntervalTree([Interval(84990, 85354), Interval(85440, 85621), Interval(86096, 86293)]),
#   'start': 84990,
#   'strand': '-',
#   'wbgene': 'WBGene00021679'},
#  'Y48G1C.9': {'alias': 'Y48G1C.9',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 92877,
#   'interval': IntervalTree([Interval(91379, 91594), Interval(92522, 92877)]),
#   'start': 91379,
#   'strand': '+',
#   'wbgene': 'WBGene00021682'},
#  'Y48G1C.1': {'alias': 'Y48G1C.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 94884,
#   'interval': IntervalTree([Interval(93023, 93136), Interval(93181, 93556), Interval(93608, 94015), Interval(94063, 94208), Interval(94268, 94568), Interval(94621, 94884)]),
#   'start': 93023,
#   'strand': '+',
#   'wbgene': 'WBGene00021676'},
#  'Y48G1C.13': {'alias': 'Y48G1C.13',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 95367,
#   'interval': IntervalTree([Interval(94827, 94929), Interval(94975, 95118), Interval(95236, 95367)]),
#   'start': 94827,
#   'strand': '-',
#   'wbgene': 'WBGene00189949'},
#  'Y48G1C.8': {'alias': 'Y48G1C.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 108223,
#   'interval': IntervalTree([Interval(96543, 96992), Interval(97599, 97960), Interval(98294, 99058), Interval(99628, 99789), Interval(100138, 100338), Interval(100394, 100625), Interval(101504, 101733), Interval(102447, 103216), Interval(104439, 104713), Interval(105435, 105621), Interval(106015, 106334), Interval(106688, 106819), Interval(107355, 107548), Interval(107595, 108223)]),
#   'start': 96543,
#   'strand': '-',
#   'wbgene': 'WBGene00021681'},
#  'F53G12.1': {'alias': 'rab-11.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 110107,
#   'interval': IntervalTree([Interval(108669, 109446), Interval(109491, 109783), Interval(109834, 109956), Interval(110004, 110107)]),
#   'start': 108669,
#   'strand': '-',
#   'wbgene': 'WBGene00004274'},
#  'F53G12.16': {'alias': 'F53G12.16',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 110771,
#   'interval': IntervalTree([Interval(110550, 110771)]),
#   'start': 110550,
#   'strand': '-',
#   'wbgene': 'WBGene00199899'},
#  'F53G12.15': {'alias': 'F53G12.15',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 110724,
#   'interval': IntervalTree([Interval(110575, 110724)]),
#   'start': 110575,
#   'strand': '+',
#   'wbgene': 'WBGene00199597'},
#  'F53G12.10': {'alias': 'rpl-7',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 112417,
#   'interval': IntervalTree([Interval(111037, 111065), Interval(111160, 111260), Interval(111509, 111707), Interval(111754, 111971), Interval(112018, 112295), Interval(112411, 112417)]),
#   'start': 111037,
#   'strand': '+',
#   'wbgene': 'WBGene00004418'},
#  'F53G12.17': {'alias': 'F53G12.17',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 111436,
#   'interval': IntervalTree([Interval(111286, 111436)]),
#   'start': 111286,
#   'strand': '-',
#   'wbgene': 'WBGene00202494'},
#  'F53G12.12': {'alias': 'F53G12.12',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 111425,
#   'interval': IntervalTree([Interval(111291, 111425)]),
#   'start': 111291,
#   'strand': '+',
#   'wbgene': 'WBGene00023461'},
#  'F53G12.9': {'alias': 'F53G12.9',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 113721,
#   'interval': IntervalTree([Interval(112284, 112481), Interval(112526, 112652), Interval(112699, 112903), Interval(113238, 113382), Interval(113425, 113527), Interval(113595, 113721)]),
#   'start': 112284,
#   'strand': '+',
#   'wbgene': 'WBGene00018774'},
#  'F53G12.8': {'alias': 'F53G12.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 114704,
#   'interval': IntervalTree([Interval(113806, 113863), Interval(114084, 114423), Interval(114543, 114704)]),
#   'start': 113806,
#   'strand': '+',
#   'wbgene': 'WBGene00018773'},
#  'F53G12.14': {'alias': '21ur-13877',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 115676,
#   'interval': IntervalTree([Interval(115655, 115676)]),
#   'start': 115655,
#   'strand': '-',
#   'wbgene': 'WBGene00171818'},
#  'F53G12.7': {'alias': 'col-45',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 117438,
#   'interval': IntervalTree([Interval(115738, 115915), Interval(116431, 116666), Interval(116718, 116974), Interval(117085, 117438)]),
#   'start': 115738,
#   'strand': '+',
#   'wbgene': 'WBGene00000622'},
#  'F53G12.6': {'alias': 'spe-8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 120870,
#   'interval': IntervalTree([Interval(118108, 118208), Interval(118552, 118953), Interval(119570, 119900), Interval(119945, 120185), Interval(120241, 120378), Interval(120487, 120710), Interval(120762, 120870)]),
#   'start': 118108,
#   'strand': '+',
#   'wbgene': 'WBGene00004962'},
#  'F53G12.5': {'alias': 'mex-3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 134065,
#   'interval': IntervalTree([Interval(127296, 127336), Interval(127384, 127436), Interval(128696, 128896), Interval(128944, 129124), Interval(129164, 129333), Interval(132100, 132553), Interval(132611, 132693), Interval(133413, 134065)]),
#   'start': 127296,
#   'strand': '+',
#   'wbgene': 'WBGene00003229'},
#  'F53G12.4': {'alias': 'F53G12.4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'five_prime_UTR', 'gene', 'mRNA'},
#   'end': 137282,
#   'interval': IntervalTree([Interval(134336, 134428), Interval(134505, 134581), Interval(135548, 135898), Interval(136234, 136712), Interval(137208, 137282)]),
#   'start': 134336,
#   'strand': '+',
#   'wbgene': 'WBGene00018772'},
#  'F53G12.3': {'alias': 'duox-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 144565,
#   'interval': IntervalTree([Interval(137844, 137886), Interval(138016, 138143), Interval(138192, 138351), Interval(138392, 138782), Interval(138828, 139032), Interval(139079, 139331), Interval(139377, 139669), Interval(139768, 139982), Interval(140135, 140292), Interval(140370, 140496), Interval(140553, 140870), Interval(140915, 141213), Interval(141680, 141854), Interval(141899, 142023), Interval(142066, 142230), Interval(142277, 142477), Interval(142546, 142671), Interval(142728, 142939), Interval(143006, 143684), Interval(144264, 144396), Interval(144439, 144565)]),
#   'start': 137844,
#   'strand': '+',
#   'wbgene': 'WBGene00018771'},
#  'F53G12.18': {'alias': 'F53G12.18',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 146468,
#   'interval': IntervalTree([Interval(144827, 144971), Interval(146390, 146468)]),
#   'start': 144827,
#   'strand': '+',
#   'wbgene': 'WBGene00271776'},
#  'F56C11.1': {'alias': 'bli-3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 154850,
#   'interval': IntervalTree([Interval(146485, 146748), Interval(146792, 146924), Interval(147053, 147731), Interval(147783, 147994), Interval(148098, 148223), Interval(149059, 149259), Interval(149302, 149472), Interval(149519, 149817), Interval(150390, 150688), Interval(150733, 151182), Interval(151226, 151383), Interval(151460, 151674), Interval(152068, 152360), Interval(152406, 152658), Interval(152705, 152909), Interval(152955, 153345), Interval(153394, 153553), Interval(153602, 153680), Interval(154758, 154850)]),
#   'start': 146485,
#   'strand': '-',
#   'wbgene': 'WBGene00000253'},
#  'F56C11.2': {'alias': 'ptr-11',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 166819,
#   'interval': IntervalTree([Interval(160171, 160546), Interval(160711, 160999), Interval(161596, 161889), Interval(162367, 162597), Interval(162644, 162717), Interval(163098, 163430), Interval(163499, 163608), Interval(163808, 164203), Interval(164676, 164765), Interval(164899, 165008), Interval(165376, 165487), Interval(165542, 165660), Interval(166001, 166104), Interval(166746, 166819)]),
#   'start': 160171,
#   'strand': '-',
#   'wbgene': 'WBGene00004225'},
#  'F56C11.6': {'alias': 'F56C11.6',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'nc_primary_transcript',
#    'three_prime_UTR'},
#   'end': 175989,
#   'interval': IntervalTree([Interval(171339, 171368), Interval(173411, 175989)]),
#   'start': 171339,
#   'strand': '+',
#   'wbgene': 'WBGene00018958'},
#  'F56C11.7': {'alias': 'F56C11.7',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 178291,
#   'interval': IntervalTree([Interval(178231, 178291)]),
#   'start': 178231,
#   'strand': '-',
#   'wbgene': 'WBGene00201018'},
#  'F56C11.5': {'alias': 'F56C11.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 182161,
#   'interval': IntervalTree([Interval(178537, 178620), Interval(180080, 180465), Interval(180599, 180698), Interval(181250, 181514), Interval(181662, 181767), Interval(181813, 182161)]),
#   'start': 178537,
#   'strand': '+',
#   'wbgene': 'WBGene00018957'},
#  'F56C11.3': {'alias': 'F56C11.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 182772,
#   'interval': IntervalTree([Interval(182078, 182345), Interval(182393, 182500), Interval(182544, 182616), Interval(182671, 182772)]),
#   'start': 182078,
#   'strand': '-',
#   'wbgene': 'WBGene00018955'},
#  'Y48G1BL.2': {'alias': 'atm-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 208465,
#   'interval': IntervalTree([Interval(183363, 183456), Interval(183506, 183629), Interval(183724, 184209), Interval(189048, 189211), Interval(189644, 189963), Interval(190556, 191067), Interval(191177, 191299), Interval(191581, 191725), Interval(191778, 191858), Interval(192691, 193095), Interval(193588, 193934), Interval(194709, 194798), Interval(195019, 195215), Interval(195356, 195523), Interval(196082, 196333), Interval(197204, 197653), Interval(197958, 198073), Interval(200046, 200503), Interval(201302, 201693), Interval(202123, 202447), Interval(203066, 203358), Interval(204261, 204685), Interval(205073, 205218), Interval(205299, 205597), Interval(206419, 206591), Interval(206692, 206781), Interval(207060, 207311), Interval(207703, 208465)]),
#   'start': 183363,
#   'strand': '+',
#   'wbgene': 'WBGene00000227'},
#  'F56C11.t1': {'alias': 'F56C11.t1',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_tRNA'},
#   'end': 185409,
#   'interval': IntervalTree([Interval(185334, 185409)]),
#   'start': 185334,
#   'strand': '+',
#   'wbgene': 'WBGene00023295'},
#  'Y48G1BL.7': {'alias': 'Y48G1BL.7',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 211732,
#   'interval': IntervalTree([Interval(209280, 209550), Interval(209957, 210100), Interval(210151, 210329), Interval(211069, 211176), Interval(211256, 211384), Interval(211494, 211732)]),
#   'start': 209280,
#   'strand': '+',
#   'wbgene': 'WBGene00021666'},
#  'Y48G1BL.3': {'alias': 'puf-10',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 215491,
#   'interval': IntervalTree([Interval(212255, 215491)]),
#   'start': 212255,
#   'strand': '-',
#   'wbgene': 'WBGene00004246'},
#  'Y48G1BL.1': {'alias': 'snpc-3.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 216996,
#   'interval': IntervalTree([Interval(216027, 216081), Interval(216144, 216277), Interval(216330, 216996)]),
#   'start': 216027,
#   'strand': '+',
#   'wbgene': 'WBGene00021662'},
#  'Y48G1BL.8': {'alias': 'Y48G1BL.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 219099,
#   'interval': IntervalTree([Interval(218059, 218205), Interval(218771, 219099)]),
#   'start': 218059,
#   'strand': '+',
#   'wbgene': 'WBGene00255594'},
#  'Y48G1BL.5': {'alias': 'Y48G1BL.5',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 221575,
#   'interval': IntervalTree([Interval(219734, 221575)]),
#   'start': 219734,
#   'strand': '-',
#   'wbgene': 'WBGene00021664'},
#  'Y48G1BM.6': {'alias': 'Y48G1BM.6',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 238252,
#   'interval': IntervalTree([Interval(231691, 238252)]),
#   'start': 231691,
#   'strand': '-',
#   'wbgene': 'WBGene00021671'},
#  'Y48G1BM.7': {'alias': 'Y48G1BM.7',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 239021,
#   'interval': IntervalTree([Interval(238615, 238772), Interval(238842, 239021)]),
#   'start': 238615,
#   'strand': '-',
#   'wbgene': 'WBGene00021672'},
#  'Y48G1BM.2': {'alias': 'Y48G1BM.2',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 245414,
#   'interval': IntervalTree([Interval(240490, 245414)]),
#   'start': 240490,
#   'strand': '+',
#   'wbgene': 'WBGene00021668'},
#  'Y48G1BM.8': {'alias': 'Y48G1BM.8',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 251580,
#   'interval': IntervalTree([Interval(248623, 251580)]),
#   'start': 248623,
#   'strand': '-',
#   'wbgene': 'WBGene00021673'},
#  'Y48G1BM.1': {'alias': 'snpc-3.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 254277,
#   'interval': IntervalTree([Interval(252117, 252183), Interval(252235, 252370), Interval(252423, 253053), Interval(253301, 253469), Interval(253707, 253803), Interval(253945, 254277)]),
#   'start': 252117,
#   'strand': '+',
#   'wbgene': 'WBGene00021667'},
#  'Y48G1BR.1': {'alias': 'Y48G1BR.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 259157,
#   'interval': IntervalTree([Interval(254276, 254802), Interval(254975, 255079), Interval(255194, 255325), Interval(255369, 255446), Interval(255817, 255960), Interval(256315, 256643), Interval(257417, 257661), Interval(258020, 258358), Interval(258547, 258683), Interval(259106, 259157)]),
#   'start': 254276,
#   'strand': '-',
#   'wbgene': 'WBGene00021675'},
#  'T13E5.1': {'alias': 'T13E5.1',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 263618,
#   'interval': IntervalTree([Interval(263501, 263618)]),
#   'start': 263501,
#   'strand': '-',
#   'wbgene': 'WBGene00220069'},
#  'C53D5.8': {'alias': '21ur-15400',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 272623,
#   'interval': IntervalTree([Interval(272602, 272623)]),
#   'start': 272602,
#   'strand': '-',
#   'wbgene': 'WBGene00169222'},
#  'C53D5.7': {'alias': '21ur-13405',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 272627,
#   'interval': IntervalTree([Interval(272606, 272627)]),
#   'start': 272606,
#   'strand': '-',
#   'wbgene': 'WBGene00166448'},
#  'C53D5.3': {'alias': 'C53D5.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 280445,
#   'interval': IntervalTree([Interval(280119, 280206), Interval(280310, 280445)]),
#   'start': 280119,
#   'strand': '+',
#   'wbgene': 'WBGene00016904'},
#  'C53D5.2': {'alias': 'marc-4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 286115,
#   'interval': IntervalTree([Interval(280119, 280206), Interval(280310, 280431), Interval(283518, 283649), Interval(284308, 284538), Interval(285007, 285211), Interval(285557, 285638), Interval(285834, 286115)]),
#   'start': 280119,
#   'strand': '+',
#   'wbgene': 'WBGene00016903'},
#  'C53D5.4': {'alias': 'ztf-3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 289185,
#   'interval': IntervalTree([Interval(286087, 286420), Interval(286873, 286997), Interval(287508, 288003), Interval(288557, 288644), Interval(288749, 288902), Interval(288972, 289185)]),
#   'start': 286087,
#   'strand': '-',
#   'wbgene': 'WBGene00016905'},
#  'C53D5.1': {'alias': 'C53D5.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 305468,
#   'interval': IntervalTree([Interval(291214, 291307), Interval(295362, 295420), Interval(295791, 295850), Interval(301208, 301234), Interval(302594, 302704), Interval(302760, 302830), Interval(303202, 303728), Interval(303787, 303909), Interval(304092, 304255), Interval(304927, 305468)]),
#   'start': 291214,
#   'strand': '+',
#   'wbgene': 'WBGene00016902'},
#  'C53D5.5': {'alias': 'C53D5.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 311130,
#   'interval': IntervalTree([Interval(305810, 306088), Interval(306289, 306608), Interval(307090, 307814), Interval(308570, 308791), Interval(309204, 309434), Interval(309541, 309763), Interval(310077, 310082), Interval(310761, 311130)]),
#   'start': 305810,
#   'strand': '-',
#   'wbgene': 'WBGene00016906'},
#  'C53D5.6': {'alias': 'imb-3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 314989,
#   'interval': IntervalTree([Interval(310980, 311576), Interval(311633, 311784), Interval(311835, 312878), Interval(312925, 313842), Interval(313887, 314102), Interval(314153, 314774), Interval(314822, 314989)]),
#   'start': 310980,
#   'strand': '-',
#   'wbgene': 'WBGene00002077'},
#  'Y48G1A.7': {'alias': 'Y48G1A.7',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 318258,
#   'interval': IntervalTree([Interval(316636, 318258)]),
#   'start': 316636,
#   'strand': '-',
#   'wbgene': 'WBGene00235385'},
#  'Y48G1A.5': {'alias': 'xpo-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 323352,
#   'interval': IntervalTree([Interval(318389, 319128), Interval(319737, 320417), Interval(321074, 322388), Interval(322784, 323093), Interval(323142, 323352)]),
#   'start': 318389,
#   'strand': '-',
#   'wbgene': 'WBGene00002079'},
#  'Y48G1A.4': {'alias': 'nol-14',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 330987,
#   'interval': IntervalTree([Interval(323787, 323934), Interval(323978, 324240), Interval(324288, 324653), Interval(325298, 326048), Interval(326958, 327245), Interval(327846, 327979), Interval(330110, 330987)]),
#   'start': 323787,
#   'strand': '+',
#   'wbgene': 'WBGene00021660'},
#  'Y48G1A.3': {'alias': 'daf-25',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 337839,
#   'interval': IntervalTree([Interval(332610, 332764), Interval(332845, 332949), Interval(333790, 334110), Interval(335708, 336143), Interval(337564, 337839)]),
#   'start': 332610,
#   'strand': '+',
#   'wbgene': 'WBGene00000917'},
#  'Y48G1A.6': {'alias': 'mbtr-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 348424,
#   'interval': IntervalTree([Interval(343068, 343649), Interval(343893, 344033), Interval(345020, 345830), Interval(346374, 346516), Interval(346560, 346742), Interval(346792, 347044), Interval(347092, 347150), Interval(348304, 348424)]),
#   'start': 343068,
#   'strand': '-',
#   'wbgene': 'WBGene00021661'},
#  'Y48G1A.2': {'alias': 'Y48G1A.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 348357,
#   'interval': IntervalTree([Interval(347468, 347581), Interval(347629, 347706), Interval(347761, 347983), Interval(348041, 348357)]),
#   'start': 347468,
#   'strand': '+',
#   'wbgene': 'WBGene00021658'},
#  'Y48G1A.1': {'alias': 'Y48G1A.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 357193,
#   'interval': IntervalTree([Interval(348459, 348619), Interval(348676, 348904), Interval(349351, 349680), Interval(350184, 350346), Interval(350640, 350985), Interval(351793, 352080), Interval(352865, 353172), Interval(353743, 353964), Interval(354380, 354699), Interval(355373, 355481), Interval(355537, 355817), Interval(356833, 356946), Interval(356993, 357193)]),
#   'start': 348459,
#   'strand': '+',
#   'wbgene': 'WBGene00021657'},
#  'R119.1': {'alias': 'R119.1',
#   'biotype': 'pseudogene',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'pseudogenic_transcript'},
#   'end': 363901,
#   'interval': IntervalTree([Interval(357239, 363901)]),
#   'start': 357239,
#   'strand': '-',
#   'wbgene': 'WBGene00020087'},
#  'R119.7': {'alias': 'rnp-8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 368319,
#   'interval': IntervalTree([Interval(364509, 364679), Interval(364735, 365191), Interval(365530, 365596), Interval(365643, 365960), Interval(366652, 367209), Interval(367745, 368319)]),
#   'start': 364509,
#   'strand': '+',
#   'wbgene': 'WBGene00020091'},
#  'R119.2': {'alias': 'R119.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 373445,
#   'interval': IntervalTree([Interval(368369, 369246), Interval(370423, 370761), Interval(371354, 371673), Interval(372616, 372707), Interval(373330, 373445)]),
#   'start': 368369,
#   'strand': '-',
#   'wbgene': 'WBGene00020088'},
#  'R119.3': {'alias': 'R119.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 379073,
#   'interval': IntervalTree([Interval(373570, 373742), Interval(377197, 377518), Interval(378570, 378641), Interval(378702, 378876), Interval(378928, 379073)]),
#   'start': 373570,
#   'strand': '-',
#   'wbgene': 'WBGene00020089'},
#  'R119.4': {'alias': 'pqn-59',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 381902,
#   'interval': IntervalTree([Interval(379070, 380128), Interval(380182, 380555), Interval(380604, 380921), Interval(380970, 381218), Interval(381265, 381470), Interval(381790, 381902)]),
#   'start': 379070,
#   'strand': '-',
#   'wbgene': 'WBGene00004143'},
#  'R119.6': {'alias': 'taf-4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 388564,
#   'interval': IntervalTree([Interval(382647, 382913), Interval(382988, 383064), Interval(383120, 383374), Interval(383428, 383564), Interval(384624, 385225), Interval(386075, 386336), Interval(388045, 388150), Interval(388376, 388564)]),
#   'start': 382647,
#   'strand': '+',
#   'wbgene': 'WBGene00006385'},
#  'R119.5': {'alias': 'R119.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 394415,
#   'interval': IntervalTree([Interval(388469, 388938), Interval(389758, 389820), Interval(390192, 390552), Interval(391034, 391100), Interval(391611, 391806), Interval(392157, 392192), Interval(392455, 392662), Interval(392997, 393122), Interval(393355, 393639), Interval(394089, 394415)]),
#   'start': 388469,
#   'strand': '-',
#   'wbgene': 'WBGene00020090'},
#  'Y50C1A.1': {'alias': 'otub-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 412915,
#   'interval': IntervalTree([Interval(398890, 399048), Interval(399188, 399269), Interval(399952, 400105), Interval(401954, 402047), Interval(402292, 402417), Interval(403513, 403717), Interval(406062, 406231), Interval(407369, 407544), Interval(408520, 408763), Interval(410343, 410626), Interval(411202, 411435), Interval(412440, 412915)]),
#   'start': 398890,
#   'strand': '+',
#   'wbgene': 'WBGene00021733'},
#  'Y50C1A.2': {'alias': 'Y50C1A.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 418660,
#   'interval': IntervalTree([Interval(412910, 413094), Interval(415871, 416096), Interval(416433, 416651), Interval(417521, 417650), Interval(417802, 417931), Interval(417977, 418097), Interval(418444, 418660)]),
#   'start': 412910,
#   'strand': '-',
#   'wbgene': 'WBGene00021734'},
#  'C07F11.2': {'alias': 'C07F11.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 423713,
#   'interval': IntervalTree([Interval(420921, 421032), Interval(421098, 421221), Interval(421564, 422182), Interval(422292, 422493), Interval(422538, 422688), Interval(422738, 422893), Interval(423500, 423713)]),
#   'start': 420921,
#   'strand': '+',
#   'wbgene': 'WBGene00015570'},
#  'C07F11.1': {'alias': 'tol-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 461605,
#   'interval': IntervalTree([Interval(443998, 444109), Interval(444253, 444376), Interval(444993, 445084), Interval(446707, 446782), Interval(446913, 447051), Interval(450196, 450306), Interval(450481, 450759), Interval(451294, 451461), Interval(455355, 455491), Interval(455545, 455721), Interval(456855, 456994), Interval(457235, 458621), Interval(459568, 460062), Interval(460949, 461605)]),
#   'start': 443998,
#   'strand': '+',
#   'wbgene': 'WBGene00006593'},
#  'W04C9.4': {'alias': 'W04C9.4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 462651,
#   'interval': IntervalTree([Interval(461994, 462173), Interval(462229, 462318), Interval(462370, 462651)]),
#   'start': 461994,
#   'strand': '+',
#   'wbgene': 'WBGene00021026'},
#  'W04C9.5': {'alias': 'W04C9.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 467131,
#   'interval': IntervalTree([Interval(462656, 462871), Interval(463234, 463421), Interval(464258, 464524), Interval(465053, 465214), Interval(465647, 465695), Interval(465995, 466124), Interval(467027, 467131)]),
#   'start': 462656,
#   'strand': '-',
#   'wbgene': 'WBGene00021027'},
#  'W04C9.7': {'alias': '21ur-8411',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 463324,
#   'interval': IntervalTree([Interval(463303, 463324)]),
#   'start': 463303,
#   'strand': '+',
#   'wbgene': 'WBGene00166632'},
#  'W04C9.8': {'alias': 'W04C9.8',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 473890,
#   'interval': IntervalTree([Interval(471134, 473890)]),
#   'start': 471134,
#   'strand': '+',
#   'wbgene': 'WBGene00235387'},
#  'W04C9.3': {'alias': 'cutl-13',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 481954,
#   'interval': IntervalTree([Interval(477581, 477732), Interval(478213, 478323), Interval(478464, 478743), Interval(478878, 479109), Interval(479933, 480181), Interval(480750, 481129), Interval(481837, 481954)]),
#   'start': 477581,
#   'strand': '+',
#   'wbgene': 'WBGene00021025'},
#  'W04C9.9': {'alias': 'W04C9.9',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 483880,
#   'interval': IntervalTree([Interval(482039, 482099), Interval(482547, 483028), Interval(483869, 483880)]),
#   'start': 482039,
#   'strand': '-',
#   'wbgene': 'WBGene00235388'},
#  'W04C9.6': {'alias': 'W04C9.6',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 487990,
#   'interval': IntervalTree([Interval(484125, 484309), Interval(484787, 484858), Interval(484906, 485002), Interval(485152, 485276), Interval(485380, 485619), Interval(486466, 486849), Interval(487586, 487727), Interval(487793, 487902), Interval(487957, 487990)]),
#   'start': 484125,
#   'strand': '-',
#   'wbgene': 'WBGene00021028'},
#  'W04C9.2': {'alias': 'W04C9.2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 489905,
#   'interval': IntervalTree([Interval(488606, 488723), Interval(488767, 488833), Interval(488881, 488944), Interval(489699, 489905)]),
#   'start': 488606,
#   'strand': '+',
#   'wbgene': 'WBGene00021024'},
#  'W04C9.1': {'alias': 'haf-4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 496150,
#   'interval': IntervalTree([Interval(489968, 490202), Interval(491194, 491302), Interval(491349, 491559), Interval(491609, 491724), Interval(491835, 492160), Interval(492224, 492351), Interval(492866, 493556), Interval(494259, 494343), Interval(494391, 494706), Interval(495827, 496150)]),
#   'start': 489968,
#   'strand': '+',
#   'wbgene': 'WBGene00001814'},
#  'Y65B4BL.3': {'alias': 'Y65B4BL.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 502042,
#   'interval': IntervalTree([Interval(496143, 496283), Interval(496329, 496464), Interval(497689, 497830), Interval(498426, 498567), Interval(499792, 500119), Interval(501928, 502042)]),
#   'start': 496143,
#   'strand': '-',
#   'wbgene': 'WBGene00022035'},
#  'Y65B4BL.4': {'alias': 'Y65B4BL.4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 506250,
#   'interval': IntervalTree([Interval(502931, 503212), Interval(504056, 504132), Interval(504224, 504278), Interval(504322, 504454), Interval(505505, 505605), Interval(505659, 505771), Interval(505819, 506049), Interval(506092, 506250)]),
#   'start': 502931,
#   'strand': '-',
#   'wbgene': 'WBGene00022036'},
#  'Y65B4BL.2': {'alias': 'deps-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 509056,
#   'interval': IntervalTree([Interval(506468, 506590), Interval(506637, 506745), Interval(506801, 507016), Interval(507064, 507225), Interval(507276, 507408), Interval(507453, 507705), Interval(507754, 507895), Interval(507943, 508048), Interval(508097, 508331), Interval(508381, 508491), Interval(508537, 508757), Interval(508804, 509056)]),
#   'start': 506468,
#   'strand': '+',
#   'wbgene': 'WBGene00022034'},
#  'Y65B4BL.7': {'alias': 'Y65B4BL.7',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 511051,
#   'interval': IntervalTree([Interval(508849, 509214), Interval(509261, 509423), Interval(509747, 509888), Interval(510738, 510935), Interval(510994, 511051)]),
#   'start': 508849,
#   'strand': '-',
#   'wbgene': 'WBGene00022039'},
#  'Y65B4BL.5': {'alias': 'acs-13',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 519800,
#   'interval': IntervalTree([Interval(511051, 511753), Interval(512480, 513090), Interval(513142, 513725), Interval(513775, 514208), Interval(515022, 515236), Interval(516350, 516456), Interval(519581, 519800)]),
#   'start': 511051,
#   'strand': '-',
#   'wbgene': 'WBGene00022037'},
#  'Y65B4BL.10': {'alias': 'Y65B4BL.10',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 512166,
#   'interval': IntervalTree([Interval(512016, 512166)]),
#   'start': 512016,
#   'strand': '+',
#   'wbgene': 'WBGene00196781'},
#  'Y65B4BL.9': {'alias': 'Y65B4BL.9',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 514492,
#   'interval': IntervalTree([Interval(514363, 514492)]),
#   'start': 514363,
#   'strand': '+',
#   'wbgene': 'WBGene00196389'},
#  'Y65B4BL.6': {'alias': 'Y65B4BL.6',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 521554,
#   'interval': IntervalTree([Interval(520108, 520534), Interval(521319, 521554)]),
#   'start': 520108,
#   'strand': '-',
#   'wbgene': 'WBGene00022038'},
#  'Y65B4BL.8': {'alias': 'Y65B4BL.8',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 526139,
#   'interval': IntervalTree([Interval(526047, 526139)]),
#   'start': 526047,
#   'strand': '-',
#   'wbgene': 'WBGene00195369'},
#  'Y65B4BL.11': {'alias': 'Y65B4BL.11',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 530326,
#   'interval': IntervalTree([Interval(530214, 530326)]),
#   'start': 530214,
#   'strand': '+',
#   'wbgene': 'WBGene00197961'},
#  'Y65B4BL.12': {'alias': 'Y65B4BL.12',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 530683,
#   'interval': IntervalTree([Interval(530394, 530683)]),
#   'start': 530394,
#   'strand': '-',
#   'wbgene': 'WBGene00200577'},
#  'Y65B4BL.1': {'alias': 'Y65B4BL.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 531998,
#   'interval': IntervalTree([Interval(530968, 531091), Interval(531266, 531348), Interval(531789, 531893), Interval(531946, 531998)]),
#   'start': 530968,
#   'strand': '+',
#   'wbgene': 'WBGene00022033'},
#  'Y65B4BM.3': {'alias': 'Y65B4BM.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 533084,
#   'interval': IntervalTree([Interval(531724, 531893), Interval(531946, 532553), Interval(532618, 533084)]),
#   'start': 531724,
#   'strand': '+',
#   'wbgene': 'WBGene00302974'},
#  'Y65B4BM.2': {'alias': 'Y65B4BM.2',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 533039,
#   'interval': IntervalTree([Interval(532967, 533039)]),
#   'start': 532967,
#   'strand': '+',
#   'wbgene': 'WBGene00220190'},
#  'Y65B4BR.8': {'alias': 'psf-3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 535344,
#   'interval': IntervalTree([Interval(534454, 534569), Interval(534617, 534724), Interval(534771, 534970), Interval(535030, 535344)]),
#   'start': 534454,
#   'strand': '+',
#   'wbgene': 'WBGene00022043'},
#  'Y65B4BR.5': {'alias': 'icd-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 536670,
#   'interval': IntervalTree([Interval(535790, 535849), Interval(535898, 536306), Interval(536349, 536670)]),
#   'start': 535790,
#   'strand': '+',
#   'wbgene': 'WBGene00022042'},
#  'Y65B4BR.10': {'alias': 'Y65B4BR.10',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 536931,
#   'interval': IntervalTree([Interval(536803, 536931)]),
#   'start': 536803,
#   'strand': '-',
#   'wbgene': 'WBGene00201456'},
#  'Y65B4BR.4': {'alias': 'wwp-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 542200,
#   'interval': IntervalTree([Interval(537121, 537243), Interval(537302, 537560), Interval(537605, 537835), Interval(538670, 538911), Interval(539452, 539727), Interval(539794, 540008), Interval(540063, 540384), Interval(540722, 540983), Interval(541063, 541285), Interval(541343, 542200)]),
#   'start': 537121,
#   'strand': '+',
#   'wbgene': 'WBGene00007009'},
#  'Y65B4BR.12': {'alias': 'Y65B4BR.12',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 539242,
#   'interval': IntervalTree([Interval(539085, 539242)]),
#   'start': 539085,
#   'strand': '+',
#   'wbgene': 'WBGene00220191'},
#  'Y65B4BR.3': {'alias': 'ptr-21',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 556638,
#   'interval': IntervalTree([Interval(550695, 550912), Interval(551712, 551909), Interval(552404, 552818), Interval(553134, 553585), Interval(553819, 554394), Interval(555023, 555097), Interval(555144, 555331), Interval(555381, 555765), Interval(555818, 556638)]),
#   'start': 550695,
#   'strand': '+',
#   'wbgene': 'WBGene00004235'},
#  'Y65B4BR.11': {'alias': 'Y65B4BR.11',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 553785,
#   'interval': IntervalTree([Interval(553657, 553785)]),
#   'start': 553657,
#   'strand': '+',
#   'wbgene': 'WBGene00202444'},
#  'Y65B4BR.2': {'alias': 'lpr-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 561671,
#   'interval': IntervalTree([Interval(557374, 557572), Interval(558403, 558543), Interval(559506, 559867), Interval(560701, 561671)]),
#   'start': 557374,
#   'strand': '+',
#   'wbgene': 'WBGene00002393'},
#  'Y65B4BR.1': {'alias': 'Y65B4BR.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 565181,
#   'interval': IntervalTree([Interval(562735, 562869), Interval(562919, 563119), Interval(563163, 563330), Interval(563373, 563457), Interval(563506, 563580), Interval(564608, 565181)]),
#   'start': 562735,
#   'strand': '+',
#   'wbgene': 'WBGene00022040'},
#  'Y65B4BR.9': {'alias': 'ceh-9',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 566414,
#   'interval': IntervalTree([Interval(565435, 565544), Interval(565692, 565880), Interval(566240, 566414)]),
#   'start': 565435,
#   'strand': '-',
#   'wbgene': 'WBGene00000434'},
#  'Y65B4BR.6': {'alias': 'grl-16',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 575120,
#   'interval': IntervalTree([Interval(572176, 572604), Interval(572888, 572993), Interval(573639, 574073), Interval(574144, 574662), Interval(574929, 575120)]),
#   'start': 572176,
#   'strand': '-',
#   'wbgene': 'WBGene00001725'},
#  'F56A6.5': {'alias': 'F56A6.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 583748,
#   'interval': IntervalTree([Interval(582287, 582625), Interval(582669, 582884), Interval(583578, 583748)]),
#   'start': 582287,
#   'strand': '-',
#   'wbgene': 'WBGene00044427'},
#  'F56A6.8': {'alias': 'F56A6.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 585376,
#   'interval': IntervalTree([Interval(585118, 585229), Interval(585274, 585376)]),
#   'start': 585118,
#   'strand': '+',
#   'wbgene': 'WBGene00235390'},
#  'F56A6.2': {'alias': 'hum-7',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 607601,
# ...
#   'start': 4557652,
#   'strand': '+',
#   'wbgene': 'WBGene00017010'},
#  'D1007.14': {'alias': 'pqn-24',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4565976,
#   'interval': IntervalTree([Interval(4564034, 4564205), Interval(4564289, 4564430), Interval(4564547, 4564657), Interval(4565134, 4565293), Interval(4565490, 4565547), Interval(4565623, 4565976)]),
#   'start': 4564034,
#   'strand': '+',
#   'wbgene': 'WBGene00004113'},
#  'D1007.13': {'alias': 'D1007.13',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 4568385,
#   'interval': IntervalTree([Interval(4566494, 4566567), Interval(4567165, 4567292), Interval(4567395, 4567507), Interval(4567880, 4568385)]),
#   'start': 4566494,
#   'strand': '+',
#   'wbgene': 'WBGene00017009'},
#  'D1007.1': {'alias': 'ceh-17',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'five_prime_UTR', 'gene', 'mRNA'},
#   'end': 4570027,
#   'interval': IntervalTree([Interval(4568961, 4569284), Interval(4569582, 4569809), Interval(4569860, 4570027)]),
#   'start': 4568961,
#   'strand': '-',
#   'wbgene': 'WBGene00000440'},
#  'D1007.2': {'alias': 'col-52',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'five_prime_UTR', 'gene', 'mRNA'},
#   'end': 4572787,
#   'interval': IntervalTree([Interval(4571213, 4571309), Interval(4571700, 4571780), Interval(4571932, 4572352), Interval(4572426, 4572588), Interval(4572638, 4572787)]),
#   'start': 4571213,
#   'strand': '-',
#   'wbgene': 'WBGene00000629'},
#  'D1007.3': {'alias': 'D1007.3',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4577204,
#   'interval': IntervalTree([Interval(4575781, 4575999), Interval(4576418, 4576584), Interval(4576704, 4576814), Interval(4576892, 4577204)]),
#   'start': 4575781,
#   'strand': '-',
#   'wbgene': 'WBGene00017001'},
#  'D1007.18': {'alias': 'D1007.18',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4579740,
#   'interval': IntervalTree([Interval(4578694, 4578918), Interval(4578976, 4579072), Interval(4579634, 4579740)]),
#   'start': 4578694,
#   'strand': '-',
#   'wbgene': 'WBGene00044421'},
#  'D1007.4': {'alias': 'D1007.4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4580601,
#   'interval': IntervalTree([Interval(4579963, 4580374), Interval(4580430, 4580601)]),
#   'start': 4579963,
#   'strand': '-',
#   'wbgene': 'WBGene00017002'},
#  'D1007.5': {'alias': 'D1007.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4583810,
#   'interval': IntervalTree([Interval(4580691, 4581240), Interval(4581662, 4582025), Interval(4582410, 4582717), Interval(4583188, 4583373), Interval(4583424, 4583508), Interval(4583558, 4583810)]),
#   'start': 4580691,
#   'strand': '-',
#   'wbgene': 'WBGene00017003'},
#  'D1007.6': {'alias': 'rps-10',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4584505,
#   'interval': IntervalTree([Interval(4583872, 4584060), Interval(4584108, 4584295), Interval(4584347, 4584505)]),
#   'start': 4583872,
#   'strand': '-',
#   'wbgene': 'WBGene00004479'},
#  'D1007.21': {'alias': '21ur-11631',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 4584788,
#   'interval': IntervalTree([Interval(4584767, 4584788)]),
#   'start': 4584767,
#   'strand': '-',
#   'wbgene': 'WBGene00168457'},
#  'D1007.22': {'alias': 'D1007.22',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 4584932,
#   'interval': IntervalTree([Interval(4584786, 4584932)]),
#   'start': 4584786,
#   'strand': '+',
#   'wbgene': 'WBGene00199533'},
#  'D1007.12': {'alias': 'rpl-24.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4586177,
#   'interval': IntervalTree([Interval(4585114, 4585221), Interval(4585442, 4585544), Interval(4585589, 4585799), Interval(4586051, 4586177)]),
#   'start': 4585114,
#   'strand': '+',
#   'wbgene': 'WBGene00004436'},
#  'D1007.20': {'alias': 'D1007.20',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 4585409,
#   'interval': IntervalTree([Interval(4585248, 4585409)]),
#   'start': 4585248,
#   'strand': '+',
#   'wbgene': 'WBGene00045094'},
#  'D1007.17': {'alias': 'mir-353',
#   'biotype': 'miRNA',
#   'chrom': 'I',
#   'element': {'gene', 'miRNA', 'pre_miRNA'},
#   'end': 4585983,
#   'interval': IntervalTree([Interval(4585873, 4585983)]),
#   'start': 4585873,
#   'strand': '+',
#   'wbgene': 'WBGene00023452'},
#  'D1007.10': {'alias': 'D1007.10',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4589463,
#   'interval': IntervalTree([Interval(4586272, 4586859), Interval(4587604, 4587702), Interval(4587747, 4587895), Interval(4587944, 4588118), Interval(4588292, 4588382), Interval(4588793, 4588928), Interval(4589239, 4589463)]),
#   'start': 4586272,
#   'strand': '+',
#   'wbgene': 'WBGene00017007'},
#  'D1007.19': {'alias': 'D1007.19',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 4589899,
#   'interval': IntervalTree([Interval(4589379, 4589899)]),
#   'start': 4589379,
#   'strand': '-',
#   'wbgene': 'WBGene00045048'},
#  'D1007.9': {'alias': 'D1007.9',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 4591587,
#   'interval': IntervalTree([Interval(4590429, 4590527), Interval(4590582, 4590742), Interval(4591362, 4591587)]),
#   'start': 4590429,
#   'strand': '+',
#   'wbgene': 'WBGene00017006'},
#  'D1007.7': {'alias': 'nrd-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4602666,
#   'interval': IntervalTree([Interval(4597913, 4598479), Interval(4598534, 4598629), Interval(4599119, 4599571), Interval(4599890, 4600025), Interval(4600086, 4600625), Interval(4600891, 4601514), Interval(4601583, 4602103), Interval(4602149, 4602408), Interval(4602477, 4602666)]),
#   'start': 4597913,
#   'strand': '-',
#   'wbgene': 'WBGene00017004'},
#  'D1007.16': {'alias': 'eaf-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4604196,
#   'interval': IntervalTree([Interval(4603216, 4603337), Interval(4603415, 4604196)]),
#   'start': 4603216,
#   'strand': '+',
#   'wbgene': 'WBGene00017011'},
#  'D1007.8': {'alias': 'D1007.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4605385,
#   'interval': IntervalTree([Interval(4604174, 4604618), Interval(4604666, 4604852), Interval(4604899, 4605385)]),
#   'start': 4604174,
#   'strand': '+',
#   'wbgene': 'WBGene00017005'},
#  'C44E4.5': {'alias': 'C44E4.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4610202,
#   'interval': IntervalTree([Interval(4605654, 4605800), Interval(4605850, 4606017), Interval(4606113, 4606432), Interval(4606483, 4606551), Interval(4607033, 4607124), Interval(4608712, 4608917), Interval(4609278, 4609498), Interval(4609631, 4609905), Interval(4609952, 4610202)]),
#   'start': 4605654,
#   'strand': '+',
#   'wbgene': 'WBGene00016654'},
#  'C44E4.1': {'alias': 'ubr-4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'nc_primary_transcript',
#    'three_prime_UTR'},
#   'end': 4633377,
#   'interval': IntervalTree([Interval(4610146, 4633377)]),
#   'start': 4610146,
#   'strand': '-',
#   'wbgene': 'WBGene00016650'},
#  'C44E4.4': {'alias': 'ssb-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4635620,
#   'interval': IntervalTree([Interval(4634102, 4634242), Interval(4634289, 4634498), Interval(4634553, 4635620)]),
#   'start': 4634102,
#   'strand': '+',
#   'wbgene': 'WBGene00016653'},
#  'C44E4.9': {'alias': '21ur-14833',
#   'biotype': 'piRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'piRNA'},
#   'end': 4635011,
#   'interval': IntervalTree([Interval(4634990, 4635011)]),
#   'start': 4634990,
#   'strand': '+',
#   'wbgene': 'WBGene00170884'},
#  'C44E4.6': {'alias': 'acbp-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4637328,
#   'interval': IntervalTree([Interval(4635721, 4636063), Interval(4636329, 4636413), Interval(4637284, 4637328)]),
#   'start': 4635721,
#   'strand': '-',
#   'wbgene': 'WBGene00016655'},
#  'C44E4.3': {'alias': 'got-2.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4640882,
#   'interval': IntervalTree([Interval(4637431, 4637808), Interval(4638087, 4638440), Interval(4638979, 4639136), Interval(4639558, 4639851), Interval(4640689, 4640882)]),
#   'start': 4637431,
#   'strand': '-',
#   'wbgene': 'WBGene00016652'},
#  'C44E4.10': {'alias': 'C44E4.10',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 4637970,
#   'interval': IntervalTree([Interval(4637832, 4637970)]),
#   'start': 4637832,
#   'strand': '+',
#   'wbgene': 'WBGene00200262'},
#  'Y119C1A.1': {'alias': 'Y119C1A.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4644069,
#   'interval': IntervalTree([Interval(4641002, 4641597), Interval(4642015, 4642249), Interval(4642463, 4642700), Interval(4643023, 4643252), Interval(4643968, 4644069)]),
#   'start': 4641002,
#   'strand': '-',
#   'wbgene': 'WBGene00022466'},
#  'B0041.3': {'alias': 'lmd-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA', 'three_prime_UTR'},
#   'end': 4645657,
#   'interval': IntervalTree([Interval(4644676, 4644763), Interval(4645184, 4645304), Interval(4645352, 4645657)]),
#   'start': 4644676,
#   'strand': '+',
#   'wbgene': 'WBGene00015008'},
#  'B0041.4': {'alias': 'rpl-4',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4646963,
#   'interval': IntervalTree([Interval(4645640, 4646231), Interval(4646280, 4646388), Interval(4646440, 4646703), Interval(4646785, 4646963)]),
#   'start': 4645640,
#   'strand': '-',
#   'wbgene': 'WBGene00004415'},
#  'B0041.9': {'alias': 'B0041.9',
#   'biotype': 'snoRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'snoRNA'},
#   'end': 4646779,
#   'interval': IntervalTree([Interval(4646725, 4646779)]),
#   'start': 4646725,
#   'strand': '-',
#   'wbgene': 'WBGene00045087'},
#  'B0041.8': {'alias': 'B0041.8',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4648275,
#   'interval': IntervalTree([Interval(4647279, 4647565), Interval(4647612, 4647881), Interval(4647930, 4648275)]),
#   'start': 4647279,
#   'strand': '+',
#   'wbgene': 'WBGene00015011'},
#  'B0041.5': {'alias': 'B0041.5',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4650770,
#   'interval': IntervalTree([Interval(4648271, 4648741), Interval(4648797, 4649101), Interval(4649178, 4649325), Interval(4649610, 4649742), Interval(4650248, 4650542), Interval(4650591, 4650770)]),
#   'start': 4648271,
#   'strand': '-',
#   'wbgene': 'WBGene00015009'},
#  'B0041.12': {'alias': 'B0041.12',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS', 'exon', 'gene', 'mRNA'},
#   'end': 4650763,
#   'interval': IntervalTree([Interval(4650730, 4650763)]),
#   'start': 4650730,
#   'strand': '-',
#   'wbgene': 'WBGene00303032'},
#  'B0041.6': {'alias': 'ptps-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4652906,
#   'interval': IntervalTree([Interval(4652144, 4652323), Interval(4652569, 4652701), Interval(4652753, 4652906)]),
#   'start': 4652144,
#   'strand': '-',
#   'wbgene': 'WBGene00015010'},
#  'B0041.2': {'alias': 'ain-2',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4660151,
#   'interval': IntervalTree([Interval(4653470, 4653542), Interval(4653597, 4653686), Interval(4655346, 4655496), Interval(4655720, 4656458), Interval(4656510, 4656780), Interval(4657205, 4657487), Interval(4657938, 4658255), Interval(4658684, 4658762), Interval(4659008, 4660151)]),
#   'start': 4653470,
#   'strand': '+',
#   'wbgene': 'WBGene00015007'},
#  'B0041.10': {'alias': 'B0041.10',
#   'biotype': 'ncRNA',
#   'chrom': 'I',
#   'element': {'exon', 'gene', 'ncRNA'},
#   'end': 4660713,
#   'interval': IntervalTree([Interval(4660520, 4660713)]),
#   'start': 4660520,
#   'strand': '+',
#   'wbgene': 'WBGene00198277'},
#  'B0041.11': {'alias': 'B0041.11',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4662219,
#   'interval': IntervalTree([Interval(4661114, 4661155), Interval(4661205, 4661956), Interval(4662002, 4662079), Interval(4662130, 4662219)]),
#   'start': 4661114,
#   'strand': '-',
#   'wbgene': 'WBGene00206362'},
#  'B0041.1': {'alias': 'B0041.1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4665331,
#   'interval': IntervalTree([Interval(4664498, 4664584), Interval(4664628, 4664782), Interval(4664834, 4665008), Interval(4665052, 4665153), Interval(4665198, 4665331)]),
#   'start': 4664498,
#   'strand': '+',
#   'wbgene': 'WBGene00015006'},
#  'B0041.7': {'alias': 'xnp-1',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4671738,
#   'interval': IntervalTree([Interval(4665743, 4666295), Interval(4666400, 4667199), Interval(4667717, 4667951), Interval(4668011, 4668709), Interval(4669226, 4669402), Interval(4669460, 4669739), Interval(4669791, 4670792), Interval(4670857, 4671424), Interval(4671478, 4671619), Interval(4671679, 4671738)]),
#   'start': 4665743,
#   'strand': '-',
#   'wbgene': 'WBGene00006961'},
#  'T04D1.3': {'alias': 'unc-57',
#   'biotype': 'protein_coding',
#   'chrom': 'I',
#   'element': {'CDS',
#    'exon',
#    'five_prime_UTR',
#    'gene',
#    'mRNA',
#    'three_prime_UTR'},
#   'end': 4679409,
#   'interval': IntervalTree([Interval(4675134, 4675474), Interval(4675747, 4675876), Interval(4675924, 4676077), Interval(4676458, 4676646), Interval(4677669, 4677724), Interval(4678567, 4679409)]),
#   'start': 4675134,
#   'strand': '+',
#   'wbgene': 'WBGene00006791'},
#  ...}

# %%
def getRangesFromTree(tree, k=10000, m=0):
    ranges = {chrom:{'+':[], '-':[]} for chrom in chroms}
    for chrom in trees:
        for strand in ['+', '-']:
            tree = trees[chrom][strand]
            for i in range(0, tree.end()+1, k):
                ranges[chrom][strand].append([curr[-1] for curr in tree2json(tree.overlap(i-m, i+k+m))])
    return ranges


def getBlocksFromTree(tree):
    #diameter of a semi-circle with given pixels: pixels*pi/2
    pixels = {'low':800, 'mid':1280, 'high':2880, 'ultra':5120}
    resolutions = {curr:pixels[curr]*3/2 for curr in pixels}
    arc_blocks = {curr:{} for curr in resolutions}

    for curr in arc_blocks:
        ranges_arc = {chrom:{'+':{}, '-':{}} for chrom in chroms}
        countd = {chrom:{'+':[], '-':[]} for chrom in chroms}
        count_tree = {chrom:{'+':None, '-':None} for chrom in chroms}
        for chrom in tree:
            chrom_len = max(tree[chrom]['+'].end(), tree[chrom]['-'].end())
            block_size =  chrom_len//resolutions[curr]
            arc_blocks[curr][chrom] = getArcChromBlock(tree[chrom], chrom_len, block_size)    
    return arc_blocks

                
def getArcChromBlock(tree, chrom_len, block_size):
    m = 0
    arcBlockInterval = {strand:None for strand in ['+', '-']}
    for strand in ['+', '-']:
        blocks = []
        curr_tree = tree[strand]
        for i in range(0, int(chrom_len//block_size+1)):
            overlap = curr_tree.overlap(i*block_size, (i+1)*block_size)
            if len(overlap) > 0: 
                blocks.append([i, i+1.01])                
        block_tree = IntervalTree.from_tuples(blocks)
        block_tree.merge_overlaps()
        arcBlockInterval[strand] = tree2json(block_tree, False)
    return arcBlockInterval


def tree2json(tree, add_data=True):
    output = []
    for branch in tree:
        start, end, data = branch
        if add_data:
            output.append([start, end, data])
        else:
            output.append([start, end])
    return sorted(output)


def getTrackData(gene2info):
    
    gene2intervals = {}
    interval2genes = {}
    interval2blocks = {}

    fields = ['chrom', 'start', 'end', 'strand', 'alias', 'biotype']
    gene2intervals = {curr:{**{'intervals':tree2json(gene2info[curr]['interval'], False)}, **{field:gene2info[curr][field] for field in fields}} for curr in gene2info}

    chroms = set([gene2info[gene]['chrom'] for gene in gene2info])
    chrom2intervals = {chrom:{'+':[], '-':[]} for chrom in chroms}

    for gene in gene2info:
        curr = gene2info[gene]
        chrom2intervals[gene2info[gene]['chrom']][gene2info[gene]['strand']].append([curr['start'], curr['end'], gene])

    chrom2trees = {}
    for chrom in chroms:
        chrom2trees[chrom] = {}
        for strand in ['+', '-']:
            chrom2trees[chrom][strand] = IntervalTree.from_tuples(chrom2intervals[chrom][strand]) 

    interval2genes = getRangesFromTree(chrom2trees)
    interval2blocks = getBlocksFromTree(chrom2trees)
    
    return gene2intervals, interval2genes, interval2blocks
    

def generateTrackData():
    tracks = []
    protein_coding = {gene:gene2info[gene] for gene in gene2info if gene2info[gene]['biotype']=='protein_coding'}
    gene2intervals, interval2genes, interval2blocks = getTrackData(protein_coding)
    tracks.append({'track':'protein coding', 'gene2intervals':gene2intervals, 'interval2genes':interval2genes, 'interval2blocks':interval2blocks})
    
    others = {gene:gene2info[gene] for gene in gene2info if gene2info[gene]['biotype']!='protein_coding'}
    gene2intervals, interval2genes, interval2blocks = getTrackData(others)
    tracks.append({'track':'others', 'gene2intervals':gene2intervals, 'interval2genes':interval2genes, 'interval2blocks':interval2blocks})
    
    return tracks
