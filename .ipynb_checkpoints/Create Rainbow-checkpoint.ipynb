# %%
# %matplotlib inline
import pandas as pd
import pickle
import os
import time
import json
import matplotlib.pylab as plt
import numpy as np
from functools import reduce
import re
#import altair as alt
#alt.renderers.enable('notebook')
#alt.data_transformers.enable('json')
import warnings
warnings.filterwarnings('ignore')
from collections import Counter
from intervaltree import Interval, IntervalTree

# %%
def getFasta(file='c_elegans.PRJNA13758.WS268.genomic.fa'):
    id2seq = {}
    with open(file) as f:
        header = ''
        seq = ''
        for line in f.readlines():
            if ">" in line:
                if len(header) != 0:
                    id2seq[header] = seq
                header = line.strip()[1:]
                seq = ''
            else:
                seq += line.strip()
        id2seq[header] = seq
    return id2seq
    
    
nts = 'AGNCT'
pairs = {nts[i]:nts[4-i] for i in range(5)}
def revComp(seq):
    return ''.join([pairs[nt] for nt in seq][::-1])

# %%
def getTranscriptGeneName(name):
    match = re.match(r'(\w+\.t?\d+)((\.\d+)|([a-z](\.\d+)*))*', name.split(":")[-1])
    if match:
        return match.group(1)
    return '-'

def getSequenceName(name):
    for field in name.split(";"):
        if 'sequence_name' in field:
            return field.split("=")[-1]
    return '-'


def getBiotype(name):
    for field in name.split(";"):
        if 'biotype' in field:
            return field.split("=")[-1]
    return '-'


def getDetails(curr):
    name = getSequenceName(curr[-1])
    start = curr[3]
    end = curr[4]
    return name, int(start), int(end)

# %%
def createIntervals(data, gene2ivs={}):
    for curr in data:
        gene = getTranscriptGeneName(curr[-1].split("=")[-1])
        try:
            gene2ivs[gene].append((int(curr[3])-1, int(curr[4])))
        except:
            gene2ivs[gene] = [(int(curr[3])-1, int(curr[4]))]
    return gene2ivs
    
def getBedData():
    bed = {}
    categories = ['genes', 'exons', '5utr', '3utr']
    for category in categories:
        with open('ws268.'+category) as f:
            bed[category] = [line.strip().split() for line in f.readlines()]
    return bed

def getGeneInfo(bed):
    gene2info = {}
    for curr in bed['genes']:
        gene, start, end = getDetails(curr)
        chrom = curr[0]
        gene2info[gene] = {'chrom':chrom, 'strand':curr[6], 'biotype':getBiotype(curr[-1])}
    return gene2info


def getMergedSequence(interval, info, id2seq):
    merged_seq = ''
    for curr in interval:
        start, end, _ = curr
        merged_seq += id2seq[info['chrom']][start:end]
    return merged_seq if info['strand'] == '+' else revComp(merged_seq)

    
def getMetaGenome(): 
    bed = getBedData()
    gene2info = getGeneInfo(bed)
    id2seq = getFasta()
    
    gene2ivs = createIntervals(bed['exons'])
    gene2ivs = createIntervals(bed['5utr'], gene2ivs)
    gene2ivs = createIntervals(bed['3utr'], gene2ivs)
    
    
    gene2seq = {}
    gene2intervals = {}
    for gene in gene2ivs:
        curr = IntervalTree.from_tuples(gene2ivs[gene])
        curr.merge_overlaps()
        gene2intervals[gene] = curr
        
        if gene in gene2info:
            gene2info[gene]['start'] = curr.begin()
            gene2info[gene]['end'] = curr.end()
            gene2seq[gene] = getMergedSequence(gene2intervals[gene], gene2info[gene], id2seq)

            
        
    return gene2intervals, gene2info, gene2seq

# %%
gene2intervals, gene2info, gene2seq = getMetaGenome()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7f602f60700c> in <module>()
# ----> 1 gene2intervals, gene2info, gene2seq = getMetaGenome()
#       2
#
# <ipython-input-4-2c01a53d7779> in getMetaGenome()
#      34
#      35 def getMetaGenome():
# ---> 36     bed = getBedData()
#      37     gene2info = getGeneInfo(bed)
#      38     id2seq = getFasta()
#
# <ipython-input-4-2c01a53d7779> in getBedData()
#      12     categories = ['genes', 'exons', '5utr', '3utr']
#      13     for category in categories:
# ---> 14         with open('ws268.'+category) as f:
#      15             bed[category] = [line.strip().split() for line in f.readlines()]
#      16     return bed
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ws268.genes'

# %%
chroms = set([gene2info[gene]['chrom'] for gene in gene2info])
ivs = {chrom:{'+':[], '-':[]} for chrom in chroms}
for gene in gene2intervals:
    if gene in gene2info:
        curr = gene2intervals[gene]
        ivs[gene2info[gene]['chrom']][gene2info[gene]['strand']].append([curr.begin(), curr.end(), gene])

for chrom in chroms:
    trees[chrom] = {}
    for strand in ['+', '-']:
        trees[chrom][strand] = IntervalTree.from_tuples(ivs[chrom][strand])

# %%
ivs['I']['+']
# Out:
# [[11494, 16837, 'Y74C9A.2'],
#  [31522, 31543, 'Y74C9A.7'],
#  [32414, 32435, 'Y74C9A.8'],
#  [43732, 44677, 'Y74C9A.1'],
#  [47466, 49857, 'Y48G1C.12'],
#  [49918, 54426, 'Y48G1C.4'],
#  [71424, 81071, 'Y48G1C.2'],
#  [81192, 91020, 'Y48G1C.10'],
#  [91379, 92877, 'Y48G1C.9'],
#  [93023, 94884, 'Y48G1C.1'],
#  [110575, 110724, 'F53G12.15'],
#  [111037, 112417, 'F53G12.10'],
#  [111291, 111425, 'F53G12.12'],
#  [112284, 113721, 'F53G12.9'],
#  [113806, 114704, 'F53G12.8'],
#  [115738, 117438, 'F53G12.7'],
#  [118108, 120870, 'F53G12.6'],
#  [127296, 134065, 'F53G12.5'],
#  [134336, 137282, 'F53G12.4'],
#  [137844, 144565, 'F53G12.3'],
#  [144827, 146468, 'F53G12.18'],
#  [171339, 175989, 'F56C11.6'],
#  [178537, 182161, 'F56C11.5'],
#  [183363, 208465, 'Y48G1BL.2'],
#  [185334, 185409, 'F56C11.t1'],
#  [209280, 211732, 'Y48G1BL.7'],
#  [216027, 216996, 'Y48G1BL.1'],
#  [218059, 219099, 'Y48G1BL.8'],
#  [240490, 245414, 'Y48G1BM.2'],
#  [252117, 254277, 'Y48G1BM.1'],
#  [280119, 280445, 'C53D5.3'],
#  [280119, 286115, 'C53D5.2'],
#  [291214, 305468, 'C53D5.1'],
#  [323787, 330987, 'Y48G1A.4'],
#  [332610, 337839, 'Y48G1A.3'],
#  [347468, 348357, 'Y48G1A.2'],
#  [348459, 357193, 'Y48G1A.1'],
#  [364509, 368319, 'R119.7'],
#  [382647, 388564, 'R119.6'],
#  [398890, 412915, 'Y50C1A.1'],
#  [420921, 423713, 'C07F11.2'],
#  [443998, 461605, 'C07F11.1'],
#  [461994, 462651, 'W04C9.4'],
#  [463303, 463324, 'W04C9.7'],
#  [471134, 473890, 'W04C9.8'],
#  [477581, 481954, 'W04C9.3'],
#  [488606, 489905, 'W04C9.2'],
#  [489968, 496150, 'W04C9.1'],
#  [506468, 509056, 'Y65B4BL.2'],
#  [512016, 512166, 'Y65B4BL.10'],
#  [514363, 514492, 'Y65B4BL.9'],
#  [530214, 530326, 'Y65B4BL.11'],
#  [530968, 531998, 'Y65B4BL.1'],
#  [531724, 533084, 'Y65B4BM.3'],
#  [532967, 533039, 'Y65B4BM.2'],
#  [534454, 535344, 'Y65B4BR.8'],
#  [535790, 536670, 'Y65B4BR.5'],
#  [537121, 542200, 'Y65B4BR.4'],
#  [539085, 539242, 'Y65B4BR.12'],
#  [550695, 556638, 'Y65B4BR.3'],
#  [553657, 553785, 'Y65B4BR.11'],
#  [557374, 561671, 'Y65B4BR.2'],
#  [562735, 565181, 'Y65B4BR.1'],
#  [585118, 585376, 'F56A6.8'],
#  [613289, 613379, 'F56A6.7'],
#  [618159, 621490, 'F56A6.1'],
#  [621707, 622187, 'Y65B4A.4'],
#  [636803, 637852, 'Y65B4A.3'],
#  [638128, 653986, 'Y65B4A.2'],
#  [654089, 658810, 'Y65B4A.1'],
#  [680407, 683472, 'Y18H1A.11'],
#  [688285, 691267, 'Y18H1A.1'],
#  [719928, 731078, 'Y18H1A.6'],
#  [740834, 741878, 'Y18H1A.18'],
#  [745858, 748288, 'Y18H1A.12'],
#  [754679, 754763, 'Y18H1A.t1'],
#  [757535, 757618, 'Y18H1A.16'],
#  [758755, 760429, 'Y18H1A.8'],
#  [763596, 770720, 'T06A4.3'],
#  [770891, 776369, 'T06A4.1'],
#  [774364, 774585, 'T06A4.5'],
#  [788096, 788219, 'T06A4.7'],
#  [803367, 835277, 'ZC123.3'],
#  [803799, 803872, 'ZC123.t1'],
#  [806509, 806659, 'ZC123.10'],
#  [809293, 809476, 'ZC123.11'],
#  [815975, 816026, 'ZC123.5'],
#  [816035, 816306, 'ZC123.9'],
#  [834415, 834465, 'ZC123.6'],
#  [837995, 841746, 'ZC123.1'],
#  [846170, 846491, 'Y95B8A.17'],
#  [853450, 872103, 'Y95B8A.8'],
#  [882917, 890194, 'Y95B8A.6'],
#  [897285, 906077, 'Y95B8A.5'],
#  [906338, 906481, 'Y95B8A.18'],
#  [907447, 911189, 'Y95B8A.4'],
#  [916167, 916317, 'Y95B8A.16'],
#  [938463, 941773, 'Y95B8A.2'],
#  [942546, 942652, 'Y95B8A.15'],
#  [943663, 947710, 'Y95B8A.1'],
#  [946026, 946117, 'Y95B8A.13'],
#  [979124, 979274, 'F54A5.4'],
#  [989670, 992181, 'F54A5.1'],
#  [996044, 1005066, 'C54G6.3'],
#  [996206, 996655, 'C54G6.6'],
#  [1006176, 1010765, 'C54G6.2'],
#  [1016402, 1017180, 'C54G6.5'],
#  [1018834, 1019229, 'Y34D9A.11'],
#  [1034442, 1040868, 'Y34D9A.3'],
#  [1041473, 1048329, 'Y34D9A.7'],
#  [1049595, 1050727, 'Y34D9A.6'],
#  [1062292, 1065269, 'Y34D9A.2'],
#  [1068483, 1075010, 'R06A10.2'],
#  [1077521, 1088473, 'R06A10.1'],
#  [1088513, 1089742, 'R06A10.5'],
#  [1107577, 1112251, 'ZK993.2'],
#  [1112417, 1115501, 'ZK993.5'],
#  [1126974, 1127057, 'ZK993.4'],
#  [1128323, 1131737, 'ZK993.1'],
#  [1156162, 1156454, 'Y48G8AL.17'],
#  [1156578, 1157474, 'Y48G8AL.8'],
#  [1157570, 1162939, 'Y48G8AL.7'],
#  [1176470, 1190829, 'Y48G8AL.6'],
#  [1193157, 1211434, 'Y48G8AL.5'],
#  [1211484, 1254669, 'Y48G8AL.1'],
#  [1254769, 1258258, 'Y48G8AL.15'],
#  [1271454, 1273029, 'Y48G8AR.8'],
#  [1278807, 1279042, 'Y48G8AR.7'],
#  [1279435, 1279484, 'Y48G8AR.5'],
#  [1282100, 1285435, 'Y48G8AR.2'],
#  [1287303, 1287959, 'Y48G8AR.3'],
#  [1305561, 1328348, 'K12C11.4'],
#  [1332697, 1334074, 'K12C11.5'],
#  [1335320, 1336867, 'K12C11.3'],
#  [1337011, 1338216, 'K12C11.6'],
#  [1338748, 1339773, 'K12C11.7'],
#  [1340677, 1341258, 'K12C11.2'],
#  [1348502, 1359595, 'Y92H12BL.1'],
#  [1365308, 1376409, 'Y92H12BL.5'],
#  [1365335, 1365398, 'Y92H12BL.6'],
#  [1394568, 1402975, 'Y92H12BR.7'],
#  [1405934, 1413100, 'Y92H12BR.6'],
#  [1416585, 1425201, 'Y92H12BR.3'],
#  [1436278, 1441331, 'Y92H12BR.8'],
#  [1444506, 1444641, 'F37F2.4'],
#  [1446496, 1465358, 'F47G6.4'],
#  [1447137, 1447210, 'F47G6.t1'],
#  [1465596, 1469587, 'F47G6.3'],
#  [1471226, 1479920, 'F47G6.2'],
#  [1483082, 1490494, 'F47G6.1'],
#  [1514754, 1540911, 'Y92H12A.4'],
#  [1543524, 1556196, 'Y92H12A.2'],
#  [1566928, 1580196, 'Y92H12A.1'],
#  [1575719, 1575792, 'Y92H12A.t1'],
#  [1581393, 1593668, 'Y73E7A.3'],
#  [1601837, 1606926, 'Y73E7A.2'],
#  [1610389, 1620080, 'Y73E7A.9'],
#  [1629002, 1633498, 'Y73E7A.1'],
#  [1634612, 1644107, 'Y73E7A.8'],
#  [1652900, 1655399, 'Y71G12B.18'],
#  [1653764, 1653785, 'Y71G12B.34'],
#  [1667500, 1669792, 'Y71G12B.17'],
#  [1680449, 1685063, 'Y71G12B.16'],
#  [1691496, 1691645, 'Y71G12B.37'],
#  [1692351, 1693675, 'Y71G12B.44'],
#  [1693189, 1693457, 'Y71G12B.41'],
#  [1696198, 1697676, 'Y71G12B.40'],
#  [1698093, 1701128, 'Y71G12B.15'],
#  [1701360, 1701808, 'Y71G12B.14'],
#  [1702104, 1708008, 'Y71G12B.13'],
#  [1709586, 1715568, 'Y71G12B.12'],
#  [1721591, 1740670, 'Y71G12B.11'],
#  [1751480, 1754410, 'Y71G12B.10'],
#  [1755328, 1766400, 'Y71G12B.9'],
#  [1767886, 1790157, 'Y71G12B.8'],
#  [1791397, 1791491, 'Y71G12B.42'],
#  [1793253, 1796424, 'Y71G12B.6'],
#  [1799716, 1806986, 'Y71G12B.5'],
#  [1808090, 1811835, 'Y71G12B.4'],
#  [1812891, 1813581, 'Y71G12B.3'],
#  [1816149, 1818496, 'Y71G12B.2'],
#  [1822400, 1823043, 'Y71G12B.39'],
#  [1823446, 1825967, 'Y71G12B.1'],
#  [1828078, 1831929, 'Y71G12B.28'],
#  [1832896, 1834764, 'C53H9.2'],
#  [1834880, 1835439, 'C53H9.1'],
#  [1835630, 1841936, 'M01D7.7'],
#  [1835737, 1835910, 'C53H9.4'],
#  [1841237, 1841334, 'M01D7.11'],
#  [1842444, 1843227, 'M01D7.6'],
#  [1843383, 1843899, 'M01D7.5'],
#  [1845220, 1850523, 'M01D7.4'],
#  [1874032, 1883639, 'Y71G12A.3'],
#  [1874109, 1874139, 'Y71G12A.5'],
#  [1895160, 1923088, 'Y71G12A.2'],
#  [1924299, 1932260, 'Y51F10.5'],
#  [1932351, 1945212, 'Y51F10.4'],
#  [1958706, 1965267, 'Y51F10.11'],
#  [1967771, 1973882, 'Y51F10.3'],
#  [1974819, 1974991, 'Y51F10.12'],
#  [1977992, 1983436, 'Y51F10.2'],
#  [2019431, 2019523, 'Y20F4.11'],
#  [2026276, 2033966, 'Y20F4.2'],
#  [2046538, 2048913, 'Y20F4.10'],
#  [2064292, 2064686, 'Y37E3.3'],
#  [2064908, 2065481, 'Y37E3.4'],
#  [2065726, 2069049, 'Y37E3.5'],
#  [2070215, 2070358, 'Y37E3.28'],
#  [2071351, 2072547, 'Y37E3.9'],
#  [2072679, 2076906, 'Y37E3.10'],
#  [2078958, 2085662, 'Y37E3.11'],
#  [2085036, 2085155, 'Y37E3.20'],
#  [2097345, 2123443, 'Y37E3.15'],
#  [2128589, 2145971, 'Y37E3.17'],
#  [2149890, 2149910, 'Y37E3.25'],
#  [2149986, 2150003, 'Y37E3.24'],
#  [2150218, 2150239, 'Y37E3.23'],
#  [2160041, 2209629, 'W03F11.6'],
#  [2216099, 2219479, 'W03F11.5'],
#  [2242229, 2247223, 'F12B6.3'],
#  [2250130, 2254901, 'F12B6.2'],
#  [2269390, 2269442, 'Y39G10AL.4'],
#  [2272358, 2272439, 'Y39G10AL.5'],
#  [2279834, 2281516, 'Y39G10AL.1'],
#  [2293131, 2297312, 'Y39G10AR.11'],
#  [2300085, 2302823, 'Y39G10AR.10'],
#  [2306984, 2308975, 'Y39G10AR.9'],
#  [2308975, 2312129, 'Y39G10AR.21'],
#  [2312495, 2313008, 'Y39G10AR.20'],
#  [2313270, 2316003, 'Y39G10AR.8'],
#  [2316306, 2318305, 'Y39G10AR.7'],
#  [2327988, 2330162, 'Y39G10AR.22'],
#  [2333311, 2338693, 'Y39G10AR.6'],
#  [2342215, 2350468, 'Y39G10AR.5'],
#  [2350840, 2350945, 'Y39G10AR.23'],
#  [2352834, 2356238, 'Y39G10AR.25'],
#  [2357882, 2372964, 'Y39G10AR.3'],
#  [2368686, 2368744, 'Y39G10AR.31'],
#  [2368782, 2368861, 'Y39G10AR.29'],
#  [2402231, 2409987, 'Y39G10AR.2'],
#  [2410189, 2410254, 'Y39G10AR.24'],
#  [2415132, 2418521, 'F23C8.13'],
#  [2434003, 2435708, 'F23C8.4'],
#  [2438766, 2442948, 'F23C8.3'],
#  [2445419, 2445983, 'F23C8.2'],
#  [2446739, 2448369, 'F23C8.1'],
#  [2483202, 2483705, 'Y74C10AR.2'],
#  [2485866, 2489780, 'Y74C10AR.1'],
#  [2489975, 2497371, 'Y23H5B.6'],
#  [2498133, 2506259, 'Y23H5B.5'],
#  [2514166, 2514255, 'Y23H5B.13'],
#  [2524531, 2524552, 'Y23H5B.11'],
#  [2533267, 2542114, 'Y23H5B.4'],
#  [2544748, 2546163, 'Y23H5B.3'],
#  [2549295, 2550543, 'Y23H5B.2'],
#  [2552986, 2555398, 'Y23H5B.1'],
#  [2556251, 2557425, 'Y23H5B.12'],
#  [2558299, 2560110, 'C55C2.4'],
#  [2560395, 2561820, 'C55C2.3'],
#  [2562615, 2563049, 'C55C2.2'],
#  [2568871, 2570746, 'C55C2.1'],
#  [2599978, 2602627, 'K07A3.3'],
#  [2605282, 2605605, 'K07A3.5'],
#  [2606753, 2617360, 'Y23H5A.5'],
#  [2614877, 2615027, 'Y23H5A.10'],
#  [2617559, 2620425, 'Y23H5A.4'],
#  [2620653, 2621859, 'Y23H5A.3'],
#  [2621956, 2623186, 'Y23H5A.2'],
#  [2629684, 2632320, 'Y23H5A.1'],
#  [2632986, 2634561, 'Y23H5A.8'],
#  [2636903, 2637591, 'F40E3.7'],
#  [2638648, 2639419, 'F40E3.3'],
#  [2642723, 2643778, 'F40E3.2'],
#  [2644964, 2645309, 'F40E3.10'],
#  [2656825, 2657013, 'F40E3.8'],
#  [2666383, 2666468, 'F32B5.17'],
#  [2668159, 2672434, 'F32B5.6'],
#  [2678058, 2678205, 'F32B5.12'],
#  [2682865, 2683011, 'F32B5.13'],
#  [2684864, 2684995, 'F32B5.14'],
#  [2688946, 2689069, 'F32B5.9'],
#  [2692073, 2692467, 'F32B5.4'],
#  [2692756, 2694084, 'F32B5.3'],
#  [2697398, 2699955, 'F32B5.2'],
#  [2700419, 2702158, 'F32B5.1'],
#  [2700642, 2700792, 'F32B5.11'],
#  [2706882, 2717549, 'Y71F9B.5'],
#  [2727013, 2727545, 'Y71F9B.4'],
#  [2730003, 2731453, 'Y71F9B.3'],
#  [2731561, 2735371, 'Y71F9B.2'],
#  [2739657, 2739796, 'Y71F9B.17'],
#  [2739990, 2740283, 'Y71F9B.19'],
#  [2742382, 2742528, 'Y71F9B.22'],
#  [2744952, 2745118, 'Y71F9B.18'],
#  [2758297, 2758405, 'Y71F9B.20'],
#  [2760303, 2761184, 'Y71F9B.24'],
#  [2774911, 2775421, 'Y71F9B.1'],
#  [2786331, 2787514, 'W03D8.10'],
#  [2791686, 2794976, 'W03D8.8'],
#  [2796129, 2797238, 'W03D8.7'],
#  [2799608, 2799671, 'W03D8.12'],
#  [2802821, 2815786, 'W03D8.6'],
#  [2816414, 2817646, 'W03D8.5'],
#  [2818743, 2820701, 'W03D8.11'],
#  [2830334, 2830483, 'W10C8.14'],
#  [2831304, 2831674, 'W10C8.8'],
#  [2835482, 2835622, 'W10C8.16'],
#  [2835836, 2835984, 'W10C8.9'],
#  [2837983, 2838050, 'W10C8.7'],
#  [2845858, 2849792, 'W10C8.1'],
#  [2855294, 2855442, 'W10C8.10'],
#  [2862402, 2864446, 'Y71F9AL.11'],
#  [2866507, 2870167, 'Y71F9AL.10'],
#  [2876931, 2878523, 'Y71F9AL.9'],
#  [2878577, 2880929, 'Y71F9AL.8'],
#  [2887799, 2889434, 'Y71F9AL.7'],
#  [2890445, 2891261, 'Y71F9AL.6'],
#  [2901324, 2903006, 'Y71F9AL.5'],
#  [2903595, 2907751, 'Y71F9AL.4'],
#  [2915175, 2918806, 'Y71F9AL.2'],
#  [2925211, 2928134, 'Y71F9AL.1'],
#  [2928394, 2929687, 'Y71F9AM.6'],
#  [2929735, 2931361, 'Y71F9AM.5'],
#  [2931460, 2947152, 'Y71F9AM.4'],
#  [2935784, 2935920, 'Y71F9AM.7'],
#  [2948428, 2948692, 'Y71F9AR.10'],
#  [2967615, 2967740, 'Y71F9AR.7'],
#  [2974916, 2974970, 'Y71F9AR.5'],
#  [2996400, 3001382, 'Y54E10BL.4'],
#  [3004048, 3005941, 'Y54E10BL.3'],
#  [3010492, 3010618, 'Y54E10BL.8'],
#  [3010687, 3011648, 'Y54E10BL.2'],
#  [3012110, 3012440, 'Y54E10BL.1'],
#  [3015741, 3021531, 'Y54E10BR.4'],
#  [3021650, 3028396, 'Y54E10BR.3'],
#  [3032934, 3034761, 'Y54E10BR.2'],
#  [3059150, 3069393, 'Y54E10BR.1'],
#  [3094512, 3109596, 'C45E1.1'],
#  [3099680, 3099769, 'C45E1.7'],
#  [3103210, 3103283, 'C45E1.9'],
#  [3105030, 3105218, 'C45E1.10'],
#  [3122010, 3127661, 'K09H9.10'],
#  [3137184, 3138447, 'K09H9.3'],
#  [3147995, 3150349, 'K09H9.2'],
#  [3152834, 3155568, 'K09H9.1'],
#  [3162802, 3163649, 'Y54E10A.7'],
#  [3163687, 3167925, 'Y54E10A.6'],
#  [3167907, 3171230, 'Y54E10A.5'],
#  [3206729, 3210226, 'Y54E10A.17'],
#  [3211045, 3217366, 'Y54E10A.4'],
#  [3229430, 3233294, 'Y54E10A.3'],
#  [3233390, 3255678, 'Y54E10A.2'],
#  [3246220, 3246370, 'Y54E10A.24'],
#  [3248204, 3248416, 'Y54E10A.25'],
#  [3248488, 3248627, 'Y54E10A.27'],
#  [3249390, 3249478, 'Y54E10A.29'],
#  [3256688, 3256764, 'Y54E10A.28'],
#  [3258999, 3259089, 'Y54E10A.20'],
#  [3259870, 3264254, 'Y44E3B.2'],
#  [3260308, 3260458, 'Y54E10A.21'],
#  [3267093, 3269116, 'W01B11.3'],
#  [3280162, 3280267, 'W01B11.7'],
#  [3287335, 3293127, 'W01B11.2'],
#  [3299605, 3300490, 'W01B11.1'],
#  [3338366, 3340219, 'Y44E3A.1'],
#  [3352414, 3359487, 'W05F2.7'],
#  [3362368, 3363362, 'W05F2.8'],
#  [3368784, 3371444, 'W05F2.6'],
#  [3371768, 3373834, 'W05F2.5'],
#  [3377397, 3377547, 'W05F2.9'],
#  [3385012, 3385084, 'F25F1.4'],
#  [3402253, 3402325, 'K03E5.7'],
#  [3405746, 3405879, 'K03E5.6'],
#  [3410011, 3415238, 'K03E5.3'],
#  [3415824, 3415924, 'K03E5.9'],
#  [3419599, 3424211, 'K03E5.2'],
#  [3427176, 3433207, 'K03E5.1'],
#  [3439107, 3449175, 'Y47G6A.28'],
#  [3449325, 3462177, 'Y47G6A.11'],
#  [3467131, 3478515, 'Y47G6A.10'],
#  [3479328, 3481439, 'Y47G6A.9'],
#  [3481986, 3484499, 'Y47G6A.8'],
#  [3502737, 3508421, 'Y47G6A.7'],
#  [3503717, 3503822, 'Y47G6A.37'],
#  [3516449, 3523387, 'Y47G6A.6'],
#  [3533884, 3539196, 'Y47G6A.5'],
#  [3547070, 3552005, 'Y47G6A.4'],
#  [3553555, 3553607, 'Y47G6A.34'],
#  [3555580, 3557402, 'Y47G6A.27'],
#  [3564039, 3565068, 'Y47G6A.33'],
#  [3601290, 3602908, 'Y47G6A.3'],
#  [3603342, 3604537, 'Y47G6A.31'],
#  [3607121, 3607477, 'Y47G6A.39'],
#  [3608394, 3612301, 'Y47G6A.2'],
#  [3611908, 3618317, 'Y47G6A.1'],
#  [3620581, 3625087, 'Y47G6A.32'],
#  [3629470, 3631112, 'T28F2.3'],
#  [3637352, 3638819, 'T28F2.2'],
#  [3639647, 3641347, 'T28F2.1'],
#  [3653996, 3655265, 'T28F2.8'],
#  [3684782, 3690192, 'D1037.1'],
#  [3698101, 3699300, 'H26D21.1'],
#  [3703541, 3704956, 'F21A9.3'],
#  [3712132, 3713134, 'F21A9.1'],
#  [3726010, 3731265, 'T12F5.3'],
#  [3731351, 3732940, 'T12F5.2'],
#  [3741455, 3742646, 'T12F5.1'],
#  [3745501, 3745522, 'T12F5.6'],
#  [3745588, 3748220, 'Y8G1A.1'],
#  [3769680, 3773876, 'ZK770.1'],
#  [3774705, 3777468, 'C32E8.6'],
#  [3782117, 3783294, 'C32E8.5'],
#  [3783834, 3784435, 'C32E8.4'],
#  [3786587, 3787494, 'C32E8.3'],
#  [3788035, 3788909, 'C32E8.2'],
#  [3796152, 3796696, 'C32E8.1'],
#  [3817995, 3821505, 'F53F10.5'],
#  [3822882, 3826514, 'F53F10.4'],
#  [3827218, 3828143, 'F53F10.3'],
#  [3828238, 3829308, 'F53F10.8'],
#  [3828842, 3829313, 'F53F10.6'],
#  [3830561, 3834124, 'F53F10.2'],
#  [3853809, 3854233, 'T03F1.11'],
#  [3867540, 3869109, 'T03F1.3'],
#  [3869213, 3870114, 'T03F1.2'],
#  [3874036, 3875995, 'T03F1.1'],
#  [3877062, 3880747, 'C50F2.3'],
#  [3881815, 3888313, 'C50F2.2'],
#  [3892331, 3895271, 'C50F2.1'],
#  [3901544, 3901729, 'C50F2.12'],
#  [3908746, 3909701, 'T20F5.2'],
#  [3916063, 3916391, 'T20F5.1'],
#  [3930829, 3931552, 'T21E3.2'],
#  [3932209, 3934813, 'T21E3.1'],
#  [3960967, 3962249, 'F47B3.4'],
#  [3964369, 3965314, 'F47B3.3'],
#  [3970373, 3971302, 'F47B3.2'],
#  [3972161, 3973703, 'F47B3.1'],
#  [3983170, 3986915, 'F28H1.3'],
#  [3987841, 3988699, 'F28H1.2'],
#  [3995708, 3996950, 'F28H1.1'],
#  [4005434, 4006019, 'F55C7.2'],
#  [4035701, 4090884, 'C09D1.1'],
#  [4043552, 4043613, 'C09D1.5'],
#  [4078903, 4079024, 'C24G7.6'],
#  [4094178, 4098330, 'C24G7.4'],
#  [4103712, 4108045, 'C24G7.2'],
#  [4109406, 4112385, 'C24G7.1'],
#  [4114733, 4116370, 'H31G24.4'],
#  [4116850, 4118163, 'H31G24.3'],
#  [4120406, 4123036, 'H31G24.2'],
#  [4123480, 4124723, 'H31G24.1'],
#  [4126055, 4129307, 'E01A2.3'],
#  [4132499, 4135239, 'E01A2.2'],
#  [4139513, 4142367, 'E01A2.1'],
#  [4149980, 4150634, 'R12E2.14'],
#  [4162034, 4165015, 'R12E2.5'],
#  [4165134, 4167229, 'R12E2.4'],
#  [4172205, 4172315, 'R12E2.16'],
#  [4175318, 4177271, 'R12E2.3'],
#  [4175996, 4176064, 'R12E2.17'],
#  [4178811, 4182158, 'R12E2.2'],
#  [4182220, 4184992, 'R12E2.1'],
#  [4185196, 4189956, 'C18E3.7'],
#  [4190141, 4193129, 'C18E3.6'],
#  [4193240, 4203303, 'C18E3.5'],
#  [4202416, 4203040, 'C18E3.4'],
#  [4203457, 4208537, 'C18E3.3'],
#  [4210978, 4212667, 'C18E3.2'],
#  [4212707, 4214317, 'C18E3.1'],
#  [4229576, 4236039, 'C43E11.6'],
#  [4236953, 4238617, 'C43E11.5'],
#  [4247753, 4249415, 'C43E11.4'],
#  [4249481, 4253170, 'C43E11.11'],
#  [4253241, 4254139, 'C43E11.12'],
#  [4254379, 4264699, 'C43E11.3'],
#  [4265108, 4267238, 'C43E11.2'],
#  [4270696, 4273332, 'C43E11.1'],
#  [4275887, 4276947, 'Y47D9A.3'],
#  [4295023, 4296741, 'Y47D9A.6'],
#  [4298183, 4302243, 'Y47D9A.2'],
#  [4303929, 4308244, 'Y47D9A.1'],
#  [4304155, 4304260, 'Y47D9A.7'],
#  [4311815, 4311888, 'T03A1.5'],
#  [4318032, 4359080, 'ZK973.6'],
#  [4359206, 4362548, 'ZK973.5'],
#  [4363414, 4364048, 'ZK973.4'],
#  [4368088, 4370504, 'ZK973.3'],
#  [4373655, 4379329, 'ZK973.2'],
#  [4382564, 4385218, 'ZK973.1'],
#  [4386784, 4401980, 'T21E12.4'],
#  [4401955, 4404585, 'T21E12.3'],
#  [4409688, 4426137, 'C11D9.1'],
#  [4410870, 4411060, 'T21E12.8'],
#  [4412015, 4412101, 'T21E12.6'],
#  [4427023, 4428026, 'C41D11.10'],
#  [4444718, 4446598, 'C41D11.2'],
#  [4457382, 4469458, 'C41D11.1'],
#  [4467873, 4469458, 'T01A4.9'],
#  [4481202, 4508930, 'T01A4.1'],
#  [4520069, 4522768, 'Y119C1B.12'],
#  [4549694, 4552758, 'Y119C1B.3'],
#  [4554125, 4555203, 'Y119C1B.1'],
#  [4557652, 4563757, 'D1007.15'],
#  [4564034, 4565976, 'D1007.14'],
#  [4566494, 4568385, 'D1007.13'],
#  [4584786, 4584932, 'D1007.22'],
#  [4585114, 4586177, 'D1007.12'],
#  [4585248, 4585409, 'D1007.20'],
#  [4586272, 4589463, 'D1007.10'],
#  [4590429, 4591587, 'D1007.9'],
#  [4603216, 4604196, 'D1007.16'],
#  [4604174, 4605385, 'D1007.8'],
#  [4605654, 4610202, 'C44E4.5'],
#  [4634102, 4635620, 'C44E4.4'],
#  [4634990, 4635011, 'C44E4.9'],
#  [4637832, 4637970, 'C44E4.10'],
#  [4644676, 4645657, 'B0041.3'],
#  [4647279, 4648275, 'B0041.8'],
#  [4653470, 4660151, 'B0041.2'],
#  [4660520, 4660713, 'B0041.10'],
#  [4664498, 4665331, 'B0041.1'],
#  [4675134, 4679409, 'T04D1.3'],
#  [4679670, 4682755, 'T04D1.2'],
#  [4699609, 4702866, 'W09C3.9'],
#  [4704597, 4705881, 'W09C3.4'],
#  [4706681, 4708762, 'W09C3.3'],
#  [4711413, 4713572, 'W09C3.2'],
#  [4717622, 4719575, 'W09C3.1'],
#  [4719788, 4721098, 'C10H11.7'],
#  [4721130, 4723960, 'C10H11.6'],
#  [4724064, 4726779, 'C10H11.5'],
#  [4727279, 4730366, 'C10H11.4'],
#  [4731602, 4735276, 'C10H11.3'],
#  [4746463, 4746903, 'C10H11.12'],
#  [4746969, 4747116, 'C10H11.14'],
#  [4747489, 4759601, 'C10H11.1'],
#  [4749895, 4750042, 'C10H11.13'],
#  [4765753, 4767515, 'M04F3.2'],
#  [4769693, 4771358, 'M04F3.1'],
#  [4778889, 4779037, 'F54D7.8'],
#  [4789189, 4789592, 'F54D7.6'],
#  [4790291, 4790649, 'F54D7.7'],
#  [4800042, 4804268, 'F54D7.3'],
#  [4805606, 4809674, 'F54D7.2'],
#  [4821932, 4824811, 'F57C9.6'],
#  [4827071, 4829794, 'F57C9.5'],
#  [4830134, 4835619, 'F57C9.4'],
#  [4836186, 4844966, 'F57C9.3'],
#  [4845012, 4847336, 'F57C9.2'],
#  [4848424, 4850717, 'F57C9.1'],
#  [4856881, 4857115, 'C01F4.7'],
#  [4862056, 4862119, 'C01F4.5'],
#  [4876142, 4876275, 'F25F8.6'],
#  [4884902, 4895495, 'F25F8.1'],
#  [4893419, 4893440, 'F25F8.3'],
#  [4896002, 4897541, 'F21F3.4'],
#  [4901917, 4903264, 'F21F3.3'],
#  [4903436, 4905138, 'F21F3.2'],
#  [4906785, 4911829, 'F21F3.1'],
#  [4918371, 4920770, 'F21F3.7'],
#  [4926591, 4928840, 'F28B3.5'],
#  [4928653, 4932147, 'F28B3.9'],
#  [4934258, 4949332, 'F28B3.4'],
#  [4959395, 4961525, 'W03G9.3'],
#  [4962450, 4964745, 'W03G9.2'],
#  [4969922, 4972243, 'W03G9.9'],
#  [4980306, 4983958, 'W03G9.1'],
#  [4984137, 4984744, 'W03G9.10'],
#  [4996838, 5003161, 'F54C1.3'],
#  [5003350, 5005163, 'F54C1.2'],
#  [5006705, 5007991, 'F54C1.9'],
#  [5008769, 5013581, 'F54C1.1'],
#  [5020747, 5023210, 'C46H11.6'],
#  [5023888, 5041149, 'C46H11.4'],
#  [5041491, 5042055, 'C46H11.3'],
#  [5044739, 5044883, 'C46H11.12'],
#  [5046473, 5046785, 'C46H11.13'],
#  [5050039, 5052523, 'C46H11.2'],
#  [5055685, 5056039, 'C46H11.1'],
#  [5073578, 5079303, 'C30F8.7'],
#  [5084897, 5085028, 'C30F8.6'],
#  [5086316, 5093793, 'C30F8.4'],
#  [5096600, 5100579, 'C30F8.3'],
#  [5100750, 5101674, 'Y110A7A.20'],
#  [5104968, 5105103, 'Y110A7A.23'],
#  [5106203, 5107625, 'Y110A7A.11'],
#  [5107832, 5110183, 'Y110A7A.10'],
#  [5119222, 5123985, 'Y110A7A.9'],
#  [5127827, 5129611, 'Y110A7A.8'],
#  [5129639, 5131065, 'Y110A7A.7'],
#  [5131287, 5134101, 'Y110A7A.6'],
#  [5134708, 5137971, 'Y110A7A.5'],
#  [5138255, 5139382, 'Y110A7A.4'],
#  [5141674, 5149226, 'Y110A7A.3'],
#  [5154528, 5158467, 'Y110A7A.2'],
#  [5165151, 5171313, 'Y110A7A.1'],
#  [5176465, 5182801, 'F56A3.3'],
#  [5182735, 5186234, 'F56A3.2'],
#  [5186925, 5188995, 'F56A3.5'],
#  [5190141, 5195243, 'F56A3.1'],
#  [5196077, 5200102, 'C32E12.2'],
#  [5197861, 5197884, 'C32E12.6'],
#  [5216230, 5216370, 'C32E12.7'],
#  [5232575, 5235222, 'C32E12.1'],
#  [5244282, 5245402, 'B0261.4'],
#  [5245742, 5263413, 'B0261.2'],
#  [5263693, 5268380, 'B0261.1'],
#  [5268418, 5269463, 'B0261.9'],
#  [5292778, 5292837, 'C01G8.10'],
#  [5314332, 5314606, 'F48C1.3'],
#  [5315916, 5316885, 'F48C1.15'],
#  [5316049, 5316197, 'F48C1.13'],
#  [5319719, 5321117, 'F48C1.2'],
#  [5324510, 5330222, 'F48C1.1'],
#  [5330474, 5330495, 'F48C1.10'],
#  [5337269, 5337419, 'F48C1.14'],
#  [5338921, 5342012, 'F55A12.6'],
#  [5344432, 5344654, 'F55A12.11'],
#  [5344871, 5345013, 'F55A12.15'],
#  [5345926, 5349657, 'F55A12.5'],
#  [5354159, 5357026, 'F55A12.4'],
#  [5358521, 5365170, 'F55A12.3'],
#  [5365264, 5366875, 'F55A12.2'],
#  [5368477, 5372643, 'F55A12.1'],
#  [5380159, 5383029, 'C24A11.2'],
#  [5401756, 5402896, 'C24A11.1'],
#  [5409665, 5409733, 'C24A11.11'],
#  [5412496, 5412640, 'C24A11.13'],
#  [5422782, 5423264, 'F27C1.4'],
#  [5426272, 5427316, 'F27C1.3'],
#  [5429931, 5430014, 'F27C1.17'],
#  [5430163, 5431449, 'F27C1.2'],
#  [5431491, 5431512, 'F27C1.14'],
#  [5434804, 5435785, 'F27C1.1'],
#  [5450435, 5450456, 'F27C1.15'],
#  [5486066, 5486087, 'C09D4.7'],
#  [5488308, 5490626, 'C09D4.3'],
#  [5491423, 5493263, 'C09D4.2'],
#  [5497678, 5505447, 'C09D4.1'],
#  [5512047, 5514557, 'F59A3.2'],
#  [5514650, 5516025, 'F59A3.12'],
#  [5516101, 5517380, 'F59A3.13'],
#  [5520388, 5529763, 'F59A3.1'],
#  [5540543, 5540564, 'F59A3.11'],
#  [5546119, 5561642, 'M01A10.2'],
#  [5563826, 5566265, 'M01A10.1'],
#  [5573213, 5576749, 'M01E11.3'],
#  [5579665, 5581979, 'M01E11.2'],
#  [5582004, 5583471, 'M01E11.1'],
#  [5619568, 5620668, 'F46F11.2'],
#  [5620750, 5623035, 'F46F11.7'],
#  [5627818, 5637622, 'F46F11.1'],
#  [5643309, 5644057, 'M01A12.4'],
#  [5644728, 5646370, 'M01A12.1'],
#  [5662142, 5667160, 'F55F8.1'],
#  [5674303, 5676609, 'T19B4.5'],
#  [5676826, 5677646, 'T19B4.4'],
#  [5678637, 5679862, 'T19B4.3'],
#  [5691837, 5697506, 'T19B4.2'],
#  [5702155, 5706838, 'T19B4.1'],
#  [5707045, 5707119, 'T19B4.8'],
#  [5716573, 5725772, 'C04F1.3'],
#  [5728297, 5728318, 'F56H1.8'],
#  [5735549, 5739421, 'F56H1.2'],
#  [5739478, 5739499, 'F56H1.9'],
#  [5739502, 5740301, 'F56H1.10'],
#  [5741185, 5741622, 'F56H1.11'],
#  [5744147, 5745617, 'F56H1.6'],
#  [5746632, 5754278, 'F56H1.1'],
#  [5764029, 5768190, 'T22E7.2'],
#  [5768918, 5773627, 'T22E7.1'],
#  [5774584, 5775610, 'B0414.3'],
#  [5776153, 5788610, 'B0414.2'],
#  [5801871, 5803266, 'B0414.1'],
#  [5807708, 5815637, 'C32F10.2'],
#  [5825719, 5825888, 'C32F10.9'],
#  [5829071, 5834640, 'C32F10.1'],
#  [5838244, 5838845, 'F33D11.16'],
#  [5840288, 5841888, 'F33D11.4'],
#  [5842708, 5844050, 'F33D11.3'],
#  [5843073, 5843163, 'F33D11.15'],
#  [5847476, 5849391, 'F33D11.2'],
#  [5852044, 5852962, 'F33D11.1'],
#  [5854782, 5854865, 'F33D11.14'],
#  [5860400, 5860547, 'F33D11.13'],
#  [5871393, 5871503, 'C34G6.13'],
#  [5872173, 5874343, 'C34G6.5'],
#  [5879138, 5879491, 'C34G6.9'],
#  [5883857, 5883989, 'C34G6.10'],
#  [5886612, 5895970, 'C34G6.4'],
#  [5896617, 5897405, 'C34G6.3'],
#  [5898302, 5902112, 'C34G6.2'],
#  [5906661, 5918229, 'C34G6.1'],
#  [5918269, 5918445, 'Y76G2B.1'],
#  [5919054, 5935416, 'B0207.5'],
#  [5937476, 5938885, 'B0207.4'],
#  [5942418, 5945537, 'B0207.3'],
#  [5955030, 5956883, 'B0207.2'],
#  [5965061, 5967211, 'B0207.1'],
#  [5968740, 5968963, 'B0207.13'],
#  [5969289, 5969354, 'B0207.15'],
#  [5986442, 5990581, 'C06A5.3'],
#  [5990740, 5992658, 'C06A5.11'],
#  [6006263, 6007295, 'C06A5.2'],
#  [6011976, 6022516, 'C06A5.1'],
#  [6022266, 6022337, 'B0025.7'],
#  [6022659, 6026874, 'B0025.2'],
#  [6027193, 6028370, 'B0025.4'],
#  [6028485, 6033457, 'B0025.1'],
#  [6035451, 6037745, 'C27A12.4'],
#  [6038405, 6041265, 'C27A12.3'],
#  [6041671, 6046018, 'C27A12.2'],
#  [6047858, 6047987, 'C27A12.11'],
#  [6051144, 6051282, 'C27A12.12'],
#  [6064087, 6065298, 'C27A12.10'],
#  [6081781, 6085962, 'ZK484.2'],
#  [6092685, 6092811, 'ZK484.11'],
#  [6093304, 6094426, 'ZK484.1'],
#  [6098926, 6099731, 'T27A3.4'],
#  [6102031, 6102463, 'T27A3.3'],
#  [6104804, 6105589, 'T27A3.8'],
#  [6110133, 6114537, 'T27A3.2'],
#  [6122589, 6126851, 'T27A3.1'],
#  [6133244, 6137978, 'F56F4.5'],
#  [6135829, 6135913, 'F56F4.t1'],
#  [6136596, 6136669, 'F56F4.t2'],
#  [6137993, 6138955, 'F56F4.4'],
#  [6141468, 6144386, 'F56F4.3'],
#  [6145454, 6146477, 'F56F4.2'],
#  [6146460, 6147068, 'F56F4.9'],
#  [6148141, 6148836, 'F56F4.1'],
#  [6149196, 6150480, 'F56F4.8'],
#  [6154074, 6157438, 'T09B4.5'],
#  [6163379, 6163599, 'T09B4.19'],
#  [6164190, 6164264, 'T09B4.t1'],
#  [6167939, 6168642, 'T09B4.4'],
#  [6169083, 6169195, 'T09B4.23'],
#  [6171594, 6171658, 'T09B4.16'],
#  [6172670, 6172796, 'T09B4.14'],
#  [6172998, 6173139, 'T09B4.17'],
#  [6174994, 6175138, 'T09B4.13'],
#  [6176251, 6178057, 'T09B4.3'],
#  [6176879, 6176943, 'T09B4.18'],
#  [6184071, 6185368, 'T09B4.2'],
#  [6185461, 6188121, 'T09B4.1'],
#  [6188156, 6192632, 'T05E7.3'],
#  [6199140, 6200193, 'T05E7.2'],
#  [6203896, 6206927, 'T05E7.1'],
#  [6212694, 6212915, 'T08B2.14'],
#  [6214664, 6215731, 'T08B2.15'],
#  [6215668, 6219911, 'T08B2.5'],
#  [6225095, 6225964, 'T08B2.4'],
#  [6232776, 6234280, 'T08B2.2'],
#  [6234707, 6235391, 'C48E7.7'],
#  [6236133, 6249762, 'C48E7.6'],
#  [6250474, 6252834, 'C48E7.5'],
#  [6252985, 6253584, 'C48E7.11'],
#  [6253700, 6254947, 'C48E7.3'],
#  [6255034, 6257791, 'C48E7.2'],
#  [6260248, 6264540, 'C48E7.1'],
#  [6280455, 6280583, 'C10G11.13'],
#  [6283495, 6283637, 'C10G11.12'],
#  [6284972, 6289340, 'C10G11.7'],
#  [6289432, 6293855, 'C10G11.6'],
#  [6295066, 6297625, 'C10G11.5'],
#  [6297766, 6299729, 'C10G11.4'],
#  [6300492, 6302298, 'C10G11.3'],
#  [6302473, 6304263, 'C10G11.2'],
#  [6307302, 6308636, 'C10G11.1'],
#  [6309113, 6310781, 'F26B1.5'],
#  [6311228, 6312413, 'F26B1.4'],
#  [6312749, 6314624, 'F26B1.6'],
#  [6315232, 6317267, 'F26B1.3'],
#  [6317700, 6320365, 'F26B1.2'],
#  [6326874, 6327972, 'F26B1.1'],
#  [6329535, 6330181, 'F26B1.8'],
#  [6342230, 6356678, 'K04F10.4'],
#  [6351171, 6351260, 'K04F10.9'],
#  [6358584, 6360457, 'K04F10.3'],
#  [6360843, 6364172, 'K04F10.2'],
#  [6364885, 6366224, 'K04F10.1'],
#  [6366330, 6368078, 'K04F10.7'],
#  [6368269, 6369598, 'ZC308.4'],
#  [6369933, 6386183, 'ZC308.1'],
#  [6402648, 6402806, 'ZC328.6'],
#  [6404586, 6405705, 'ZC328.1'],
#  [6407457, 6409212, 'ZC328.4'],
#  [6412869, 6413067, 'R10A10.3'],
#  [6418564, 6418809, 'R10A10.1'],
#  [6421977, 6425794, 'F37E3.1'],
#  [6432138, 6432212, 'F37E3.4'],
#  [6436057, 6441192, 'T23H2.2'],
#  [6447303, 6453933, 'T23H2.1'],
#  [6459476, 6459596, 'K06A5.10'],
#  [6460432, 6464286, 'K06A5.4'],
#  [6466751, 6467515, 'K06A5.3'],
#  [6468112, 6469392, 'K06A5.2'],
#  [6473206, 6476756, 'K06A5.1'],
#  [6482450, 6485857, 'C55B7.6'],
#  [6494215, 6496109, 'C55B7.5'],
#  [6497435, 6499560, 'C55B7.4'],
#  [6499536, 6501410, 'C55B7.3'],
#  [6507893, 6511630, 'C55B7.2'],
#  [6513927, 6517507, 'C55B7.1'],
#  [6518396, 6518619, 'C55B7.13'],
#  [6525044, 6528689, 'T10E9.4'],
#  [6534071, 6539193, 'T10E9.3'],
#  [6535366, 6535436, 'T10E9.11'],
#  [6542089, 6544966, 'T10E9.2'],
#  [6545109, 6546593, 'T10E9.1'],
#  [6546721, 6546742, 'T10E9.10'],
#  [6554728, 6558623, 'F57B10.7'],
#  [6558695, 6562346, 'F57B10.6'],
#  [6562648, 6562669, 'F57B10.15'],
#  [6562698, 6563660, 'F57B10.5'],
#  [6566172, 6568905, 'F57B10.4'],
#  [6569493, 6572598, 'F57B10.3'],
#  [6574003, 6585510, 'F57B10.1'],
#  [6577334, 6577476, 'F57B10.18'],
#  [6582790, 6582913, 'F48A9.6'],
#  [6585038, 6587882, 'F48A9.3'],
#  [6592081, 6592231, 'F48A9.5'],
#  [6592331, 6593831, 'F48A9.2'],
#  [6594319, 6596231, 'F48A9.1'],
#  [6596918, 6598928, 'D2092.6'],
#  [6608340, 6608517, 'D2092.13'],
#  [6615513, 6615591, 'D2092.12'],
#  [6616303, 6618560, 'D2092.7'],
#  [6620664, 6621292, 'D2092.8'],
#  [6632450, 6632594, 'D2092.14'],
#  [6651219, 6655430, 'ZC581.3'],
#  [6655607, 6658371, 'ZC581.2'],
#  [6659271, 6659356, 'ZC581.11'],
#  [6663049, 6665160, 'ZC581.1'],
#  [6667204, 6667349, 'ZC581.12'],
#  [6669183, 6669592, 'C17F3.1'],
#  [6682332, 6683697, 'C17F3.3'],
#  [6710215, 6710543, 'T23B3.9'],
#  [6710869, 6711201, 'T23B3.8'],
#  [6711511, 6712327, 'T23B3.3'],
#  [6715948, 6717090, 'T23B3.2'],
#  [6717818, 6719430, 'T23B3.1'],
#  [6724916, 6728330, 'W02D3.3'],
#  [6736679, 6741175, 'W02D3.2'],
#  [6741273, 6741877, 'W02D3.1'],
#  [6741983, 6742358, 'W02D3.12'],
#  [6757174, 6757233, 'F08B6.6'],
#  [6757762, 6758178, 'F08B6.2'],
#  [6760415, 6761435, 'F08B6.1'],
#  [6780805, 6784396, 'C37A2.4'],
#  [6781802, 6781874, 'C37A2.t1'],
#  [6784853, 6787139, 'C37A2.3'],
#  [6791024, 6797470, 'C37A2.2'],
#  [6800385, 6804860, 'E02D9.1'],
#  [6810438, 6810571, 'K02F2.8'],
#  [6812663, 6814248, 'K02F2.4'],
#  [6814510, 6834687, 'K02F2.3'],
#  [6828678, 6828736, 'K02F2.7'],
#  [6831470, 6831522, 'K02F2.9'],
#  [6835505, 6835631, 'K02F2.11'],
#  [6836374, 6838140, 'K02F2.2'],
#  [6838353, 6843343, 'K02F2.1'],
#  [6843588, 6845134, 'H27M09.4'],
#  [6847133, 6847308, 'H27M09.7'],
#  [6847510, 6849923, 'H27M09.3'],
#  [6850408, 6851356, 'H27M09.2'],
#  [6851371, 6854140, 'H27M09.1'],
#  [6854687, 6857529, 'T21G5.3'],
#  [6860584, 6860660, 'T21G5.10'],
#  [6862396, 6870424, 'T21G5.6'],
#  [6866588, 6866731, 'T21G5.8'],
#  [6870414, 6871911, 'T21G5.2'],
#  [6874303, 6876928, 'T21G5.1'],
#  [6882057, 6882188, 'T21G5.7'],
#  [6887833, 6887895, 'C48B6.12'],
#  [6888743, 6888884, 'C48B6.11'],
#  [6889253, 6891501, 'C48B6.4'],
#  [6893302, 6893447, 'C48B6.13'],
#  [6915048, 6916609, 'C48B6.3'],
#  [6916765, 6917560, 'C48B6.2'],
#  [6926261, 6929664, 'T10B11.3'],
#  [6931137, 6936928, 'T10B11.2'],
#  [6934995, 6935252, 'T10B11.10'],
#  [6951134, 6951982, 'T10B11.1'],
#  [6974557, 6977100, 'C30F12.7'],
#  [6979628, 6979773, 'C30F12.8'],
#  [6989066, 6992106, 'C30F12.6'],
#  [6992717, 6992853, 'C30F12.9'],
#  [7005442, 7009190, 'H06O01.3'],
#  [7013217, 7013578, 'H06O01.5'],
#  [7021406, 7021584, 'VF15C11L.1'],
#  [7021945, 7029076, 'F15C11.2'],
#  [7033810, 7033950, 'F15C11.6'],
#  [7038899, 7048832, 'F15C11.1'],
#  [7057169, 7059351, 'W01A8.1'],
#  [7065262, 7067899, 'W01A8.3'],
#  [7069439, 7070728, 'W01A8.5'],
#  [7090622, 7091371, 'F22D6.4'],
#  [7095485, 7098406, 'F22D6.6'],
#  [7098648, 7099005, 'F22D6.14'],
#  [7099809, 7101775, 'F22D6.9'],
#  [7103993, 7104058, 'F22D6.18'],
#  [7105301, 7106926, 'F22D6.10'],
#  [7110239, 7112287, 'F22D6.11'],
#  [7112902, 7115001, 'F22D6.12'],
#  [7117807, 7121545, 'K10D3.1'],
#  [7132746, 7134312, 'K10D3.3'],
#  [7159713, 7160917, 'K07G5.2'],
#  [7161015, 7166518, 'K07G5.3'],
#  [7169996, 7172189, 'K07G5.5'],
#  [7181233, 7181363, 'M05B5.8'],
#  [7183052, 7185709, 'M05B5.6'],
#  [7185694, 7188298, 'M05B5.3'],
#  [7188464, 7190581, 'M05B5.4'],
#  [7201775, 7201829, 'C01H6.10'],
#  [7208830, 7208922, 'C01H6.11'],
#  [7210514, 7212579, 'C01H6.4'],
#  [7214744, 7221781, 'C01H6.5'],
#  [7222295, 7224381, 'C01H6.6'],
#  [7224655, 7227767, 'C01H6.7'],
#  [7227858, 7229434, 'C01H6.8'],
#  [7235351, 7235372, 'R06C7.11'],
#  [7235370, 7238790, 'R06C7.1'],
#  [7244936, 7246295, 'R06C7.4'],
#  [7251940, 7255223, 'R06C7.8'],
#  [7255379, 7258700, 'R06C7.9'],
#  [7259838, 7259938, 'R06C7.12'],
#  [7267094, 7267226, 'F21C3.10'],
#  [7291271, 7293331, 'F13G3.1'],
#  [7294037, 7295687, 'F13G3.2'],
#  [7295752, 7297004, 'F13G3.12'],
#  [7304917, 7307010, 'F13G3.7'],
#  [7305052, 7305103, 'F13G3.15'],
#  [7307116, 7308626, 'F13G3.11'],
#  [7317645, 7318337, 'F52A8.1'],
#  [7333034, 7334533, 'F52A8.8'],
#  [7339203, 7345949, 'F52A8.4'],
#  [7347221, 7350386, 'F52A8.6'],
#  [7352414, 7353701, 'F07A5.2'],
#  [7354490, 7357180, 'F07A5.3'],
#  [7384397, 7388792, 'C15A11.2'],
#  [7400589, 7400610, 'C15A11.8'],
#  [7401673, 7402753, 'C15A11.5'],
#  [7404949, 7408511, 'C15A11.7'],
#  [7422784, 7454088, 'ZK524.2'],
#  [7454659, 7456953, 'ZK524.1'],
#  [7475045, 7475283, 'T28F4.7'],
#  [7480107, 7483392, 'T28F4.2'],
#  [7489893, 7490428, 'T28F4.8'],
#  [7491815, 7492934, 'T28F4.5'],
#  [7495436, 7503577, 'C26C6.1'],
#  [7505950, 7506693, 'C26C6.6'],
#  [7508720, 7512593, 'C26C6.7'],
#  [7518821, 7519001, 'C26C6.13'],
#  [7519239, 7519339, 'C26C6.14'],
#  [7522115, 7526703, 'C26C6.2'],
#  [7527223, 7531715, 'C26C6.3'],
#  [7532314, 7535997, 'C26C6.4'],
#  [7552974, 7554553, 'T25G3.1'],
#  [7554854, 7559916, 'T25G3.2'],
#  [7559838, 7562349, 'T25G3.3'],
#  [7564583, 7567719, 'T25G3.4'],
#  [7574194, 7578564, 'D2030.2'],
#  [7582105, 7583349, 'D2030.5'],
#  [7583809, 7585340, 'D2030.12'],
#  [7588579, 7590565, 'D2030.7'],
#  [7590542, 7591204, 'D2030.11'],
#  [7591287, 7595198, 'D2030.8'],
#  [7596506, 7602203, 'D2030.9'],
#  [7602306, 7608245, 'D2030.10'],
#  [7614175, 7634135, 'F29D11.1'],
#  [7667728, 7669900, 'F26A3.5'],
#  [7671531, 7671642, 'F26A3.11'],
#  [7676667, 7679061, 'T24B1.1'],
#  [7679453, 7683041, 'T23G11.7'],
#  [7683340, 7694210, 'T23G11.5'],
#  [7694324, 7695233, 'T23G11.4'],
#  [7695660, 7698227, 'T23G11.3'],
#  [7698300, 7699037, 'T23G11.10'],
#  [7699542, 7700958, 'T23G11.2'],
#  [7701120, 7701389, 'T23G11.11'],
#  [7701176, 7701313, 'T23G11.12'],
#  [7702428, 7704584, 'F27D4.1'],
#  [7715955, 7716041, 'F27D4.10'],
#  [7722083, 7723116, 'F27D4.3'],
#  [7725018, 7727112, 'F27D4.4'],
#  [7727266, 7729092, 'F27D4.5'],
#  [7729183, 7729878, 'F27D4.8'],
#  [7731120, 7737995, 'F27D4.6'],
#  [7738670, 7738691, 'F58H10.2'],
#  [7755777, 7756353, 'F58H10.1'],
#  [7773179, 7777652, 'H15N14.1'],
#  [7777669, 7778011, 'H15N14.3'],
#  [7779418, 7785798, 'H15N14.4'],
#  [7798812, 7798947, 'D2005.9'],
#  [7814971, 7819410, 'D2005.4'],
#  [7815027, 7815048, 'D2005.8'],
#  [7819578, 7820489, 'D2005.7'],
#  [7820830, 7826433, 'D2005.5'],
#  ...]

# %%
k = 10000
m = 100
ranges = {chrom:{'+':{}, '-':{}} for chrom in chroms}
for chrom in trees:
    for strand in ['+', '-']:
        tree = trees[chrom][strand]
        for i in range(0, tree.end()+1, k):
            ranges[chrom][strand][i//k] =tree.overlap(i-m, i+k+m)

# %%
ranges['IV']['+'][1600]
# Out:
# {Interval(16003006, 16003027, 'Y105C5B.129'),
#  Interval(16003009, 16003030, 'Y105C5B.43'),
#  Interval(16003333, 16003354, 'Y105C5B.626'),
#  Interval(16003506, 16003527, 'Y105C5B.443'),
#  Interval(16003596, 16003617, 'Y105C5B.733'),
#  Interval(16003738, 16003759, 'Y105C5B.468'),
#  Interval(16003741, 16003762, 'Y105C5B.631'),
#  Interval(16003948, 16003969, 'Y105C5B.322'),
#  Interval(16004253, 16004274, 'Y105C5B.38'),
#  Interval(16004714, 16004735, 'Y105C5B.1013'),
#  Interval(16005041, 16005062, 'Y105C5B.160'),
#  Interval(16005212, 16005233, 'Y105C5B.1364'),
#  Interval(16005804, 16005954, 'Y105C5B.1416'),
#  Interval(16006766, 16006787, 'Y105C5B.693'),
#  Interval(16007139, 16007160, 'Y105C5B.1108')}

# %%
k = 1000
m = 0
ranges_arc = {chrom:{'+':{}, '-':{}} for chrom in chroms}
countd = {chrom:{'+':[], '-':[]} for chrom in chroms}
count_tree = {chrom:{'+':None, '-':None} for chrom in chroms}
for chrom in trees:
    for strand in ['+', '-']:
        blocks = []
        tree = trees[chrom][strand]
        for i in range(0, tree.end()+1, k):
            overlap = tree.overlap(i-m, i+k+m)
            block_pos = i//k
            ranges_arc[chrom][strand][block_pos] = len(overlap)
            if len(overlap) > 0:   
                blocks.append([block_pos, block_pos+1.1])
        block_tree = IntervalTree.from_tuples(blocks)
        block_tree.merge_overlaps()
        count_tree[chrom][strand] = block_tree

# %%
a = [(1,2), [2,3]]
temp = IntervalTree.from_tuples(a)
temp
# Out:
# IntervalTree([Interval(1, 2), Interval(2, 3)])

# %%
temp.merge_overlaps()
temp
# Out:
# IntervalTree([Interval(1, 2), Interval(2, 3)])

# %%
count_tree
# Out:
# {'V': {'+': IntervalTree([Interval(0, 7.1), Interval(20, 44.1), Interval(45, 47.1), Interval(48, 50.1), Interval(59, 64.1), Interval(87, 88.1), Interval(102, 103.1), Interval(104, 119.1), Interval(128, 132.1), Interval(138, 141.1), Interval(142, 147.1), Interval(156, 185.1), Interval(186, 210.1), Interval(217, 223.1), Interval(243, 245.1), Interval(268, 272.1), Interval(297, 301.1), Interval(318, 324.1), Interval(325, 327.1), Interval(343, 348.1), Interval(349, 374.1), Interval(376, 378.1), Interval(381, 399.1), Interval(400, 402.1), Interval(404, 406.1), Interval(408, 411.1), Interval(419, 427.1), Interval(429, 437.1), Interval(438, 439.1), Interval(449, 457.1), Interval(459, 468.1), Interval(472, 481.1), Interval(482, 483.1), Interval(484, 499.1), Interval(504, 507.1), Interval(527, 538.1), Interval(539, 542.1), Interval(543, 546.1), Interval(560, 565.1), Interval(576, 584.1), Interval(585, 596.1), Interval(600, 603.1), Interval(607, 609.1), Interval(610, 617.1), Interval(619, 622.1), Interval(630, 634.1), Interval(636, 640.1), Interval(644, 645.1), Interval(647, 650.1), Interval(664, 666.1), Interval(677, 691.1), Interval(700, 704.1), Interval(707, 711.1), Interval(728, 735.1), Interval(742, 751.1), Interval(753, 758.1), Interval(762, 785.1), Interval(787, 790.1), Interval(809, 819.1), Interval(826, 829.1), Interval(833, 836.1), Interval(839, 840.1), Interval(844, 846.1), Interval(847, 854.1), Interval(856, 863.1), Interval(874, 878.1), Interval(879, 882.1), Interval(891, 892.1), Interval(893, 895.1), Interval(904, 926.1), Interval(930, 931.1), Interval(936, 940.1), Interval(970, 971.1), Interval(979, 980.1), Interval(982, 997.1), Interval(1008, 1019.1), Interval(1055, 1056.1), Interval(1061, 1068.1), Interval(1075, 1080.1), Interval(1084, 1090.1), Interval(1092, 1099.1), Interval(1101, 1105.1), Interval(1112, 1130.1), Interval(1134, 1140.1), Interval(1141, 1147.1), Interval(1150, 1154.1), Interval(1156, 1159.1), Interval(1165, 1175.1), Interval(1176, 1182.1), Interval(1183, 1185.1), Interval(1196, 1220.1), Interval(1260, 1263.1), Interval(1264, 1274.1), Interval(1279, 1280.1), Interval(1292, 1293.1), Interval(1315, 1316.1), Interval(1326, 1327.1), Interval(1338, 1339.1), Interval(1352, 1357.1), Interval(1371, 1372.1), Interval(1412, 1413.1), Interval(1439, 1443.1), Interval(1445, 1446.1), Interval(1447, 1449.1), Interval(1451, 1457.1), Interval(1460, 1462.1), Interval(1464, 1472.1), Interval(1475, 1480.1), Interval(1482, 1485.1), Interval(1494, 1498.1), Interval(1499, 1501.1), Interval(1506, 1509.1), Interval(1522, 1526.1), Interval(1542, 1543.1), Interval(1548, 1551.1), Interval(1558, 1559.1), Interval(1567, 1592.1), Interval(1594, 1595.1), Interval(1596, 1599.1), Interval(1601, 1604.1), Interval(1610, 1613.1), Interval(1630, 1631.1), Interval(1632, 1658.1), Interval(1660, 1666.1), Interval(1667, 1674.1), Interval(1682, 1690.1), Interval(1697, 1698.1), Interval(1702, 1705.1), Interval(1708, 1716.1), Interval(1717, 1728.1), Interval(1729, 1731.1), Interval(1733, 1739.1), Interval(1743, 1748.1), Interval(1752, 1754.1), Interval(1757, 1766.1), Interval(1788, 1800.1), Interval(1805, 1806.1), Interval(1807, 1810.1), Interval(1821, 1824.1), Interval(1842, 1845.1), Interval(1846, 1849.1), Interval(1855, 1856.1), Interval(1869, 1876.1), Interval(1895, 1914.1), Interval(1918, 1923.1), Interval(1927, 1932.1), Interval(1938, 1939.1), Interval(1944, 1955.1), Interval(1957, 1958.1), Interval(1962, 1964.1), Interval(1969, 1978.1), Interval(1979, 1983.1), Interval(1988, 1989.1), Interval(2005, 2014.1), Interval(2019, 2025.1), Interval(2030, 2031.1), Interval(2049, 2051.1), Interval(2057, 2062.1), Interval(2068, 2070.1), Interval(2086, 2092.1), Interval(2096, 2101.1), Interval(2105, 2106.1), Interval(2110, 2115.1), Interval(2119, 2121.1), Interval(2122, 2131.1), Interval(2147, 2149.1), Interval(2151, 2159.1), Interval(2169, 2187.1), Interval(2188, 2190.1), Interval(2192, 2197.1), Interval(2202, 2203.1), Interval(2207, 2211.1), Interval(2 ...
#   '-': IntervalTree([Interval(0, 1.1), Interval(6, 9.1), Interval(12, 14.1), Interval(49, 57.1), Interval(63, 84.1), Interval(87, 88.1), Interval(103, 105.1), Interval(118, 123.1), Interval(124, 129.1), Interval(132, 135.1), Interval(137, 142.1), Interval(147, 153.1), Interval(163, 174.1), Interval(210, 213.1), Interval(222, 227.1), Interval(228, 235.1), Interval(236, 243.1), Interval(244, 258.1), Interval(271, 273.1), Interval(276, 282.1), Interval(300, 312.1), Interval(323, 331.1), Interval(334, 337.1), Interval(372, 381.1), Interval(401, 404.1), Interval(410, 418.1), Interval(436, 450.1), Interval(467, 469.1), Interval(480, 484.1), Interval(499, 504.1), Interval(508, 510.1), Interval(511, 527.1), Interval(545, 557.1), Interval(564, 569.1), Interval(570, 575.1), Interval(583, 587.1), Interval(603, 610.1), Interval(622, 629.1), Interval(634, 635.1), Interval(640, 647.1), Interval(651, 677.1), Interval(690, 700.1), Interval(710, 713.1), Interval(715, 720.1), Interval(722, 729.1), Interval(734, 739.1), Interval(751, 753.1), Interval(758, 762.1), Interval(802, 805.1), Interval(812, 814.1), Interval(819, 825.1), Interval(834, 845.1), Interval(853, 856.1), Interval(865, 867.1), Interval(869, 872.1), Interval(877, 879.1), Interval(882, 891.1), Interval(892, 904.1), Interval(939, 950.1), Interval(951, 965.1), Interval(970, 971.1), Interval(979, 980.1), Interval(998, 1004.1), Interval(1018, 1034.1), Interval(1039, 1040.1), Interval(1042, 1049.1), Interval(1050, 1059.1), Interval(1062, 1068.1), Interval(1079, 1085.1), Interval(1130, 1135.1), Interval(1140, 1142.1), Interval(1158, 1166.1), Interval(1172, 1173.1), Interval(1181, 1201.1), Interval(1219, 1221.1), Interval(1223, 1237.1), Interval(1262, 1264.1), Interval(1274, 1286.1), Interval(1288, 1300.1), Interval(1315, 1318.1), Interval(1332, 1364.1), Interval(1373, 1384.1), Interval(1391, 1412.1), Interval(1422, 1426.1), Interval(1427, 1433.1), Interval(1434, 1436.1), Interval(1444, 1445.1), Interval(1449, 1451.1), Interval(1454, 1455.1), Interval(1462, 1465.1), Interval(1484, 1492.1), Interval(1501, 1506.1), Interval(1510, 1512.1), Interval(1518, 1522.1), Interval(1526, 1546.1), Interval(1551, 1554.1), Interval(1558, 1559.1), Interval(1603, 1608.1), Interval(1612, 1627.1), Interval(1628, 1632.1), Interval(1658, 1660.1), Interval(1673, 1681.1), Interval(1690, 1695.1), Interval(1697, 1702.1), Interval(1730, 1732.1), Interval(1738, 1742.1), Interval(1743, 1744.1), Interval(1748, 1752.1), Interval(1754, 1756.1), Interval(1765, 1772.1), Interval(1773, 1775.1), Interval(1778, 1783.1), Interval(1793, 1794.1), Interval(1799, 1805.1), Interval(1809, 1822.1), Interval(1823, 1831.1), Interval(1848, 1857.1), Interval(1863, 1869.1), Interval(1870, 1872.1), Interval(1875, 1883.1), Interval(1889, 1890.1), Interval(1908, 1909.1), Interval(1913, 1918.1), Interval(1919, 1921.1), Interval(1923, 1926.1), Interval(1938, 1939.1), Interval(1953, 1957.1), Interval(1960, 1965.1), Interval(1978, 1980.1), Interval(1982, 1988.1), Interval(1989, 1993.1), Interval(1996, 2005.1), Interval(2013, 2014.1), Interval(2015, 2017.1), Interval(2020, 2021.1), Interval(2024, 2028.1), Interval(2030, 2032.1), Interval(2033, 2036.1), Interval(2038, 2047.1), Interval(2049, 2054.1), Interval(2061, 2067.1), Interval(2069, 2073.1), Interval(2091, 2096.1), Interval(2100, 2110.1), Interval(2115, 2119.1), Interval(2120, 2122.1), Interval(2131, 2141.1), Interval(2144, 2147.1), Interval(2148, 2151.1), Interval(2158, 2160.1), Interval(2161, 2167.1), Interval(2189, 2192.1), Interval(2198, 2207.1), Interval(2210, 2215.1), Interval(2242, 2243.1), Interval(2247, 2250.1), Interval(2252, 2255.1), Interval(2257, 2260.1), Interval(2262, 2268.1), Interval(2271, 2279.1), Interval(2288, 2291.1), Interval(2296, 2310.1), Interval(2313, 2323.1), Interval(2324, 2327.1), Interval(2329, 2330.1), Interval(2334, 2345.1), Interval(2348, 2351.1), Interval(2353, 2357.1), Interval(2361, 2374.1), Interval(2375, 2380.1), Interval(2406, 2408.1), Interval(2423, 2 ...
#  'X': {'+': IntervalTree([Interval(0, 8.1), Interval(13, 16.1), Interval(34, 42.1), Interval(47, 61.1), Interval(78, 81.1), Interval(86, 88.1), Interval(90, 91.1), Interval(114, 122.1), Interval(131, 133.1), Interval(138, 140.1), Interval(146, 149.1), Interval(164, 172.1), Interval(173, 180.1), Interval(182, 198.1), Interval(199, 208.1), Interval(211, 212.1), Interval(221, 226.1), Interval(230, 232.1), Interval(239, 241.1), Interval(248, 250.1), Interval(256, 261.1), Interval(274, 278.1), Interval(284, 286.1), Interval(287, 289.1), Interval(297, 300.1), Interval(301, 309.1), Interval(313, 315.1), Interval(322, 324.1), Interval(326, 335.1), Interval(353, 363.1), Interval(364, 365.1), Interval(372, 377.1), Interval(397, 401.1), Interval(404, 406.1), Interval(410, 411.1), Interval(421, 424.1), Interval(433, 435.1), Interval(460, 467.1), Interval(476, 479.1), Interval(481, 488.1), Interval(489, 499.1), Interval(503, 504.1), Interval(507, 508.1), Interval(538, 539.1), Interval(543, 545.1), Interval(558, 564.1), Interval(593, 597.1), Interval(598, 599.1), Interval(602, 605.1), Interval(607, 609.1), Interval(629, 633.1), Interval(650, 651.1), Interval(656, 659.1), Interval(664, 666.1), Interval(673, 677.1), Interval(692, 704.1), Interval(706, 708.1), Interval(737, 743.1), Interval(750, 751.1), Interval(763, 767.1), Interval(768, 776.1), Interval(777, 781.1), Interval(788, 797.1), Interval(802, 805.1), Interval(830, 838.1), Interval(852, 854.1), Interval(859, 863.1), Interval(865, 866.1), Interval(872, 876.1), Interval(877, 884.1), Interval(888, 889.1), Interval(913, 921.1), Interval(924, 943.1), Interval(950, 961.1), Interval(980, 984.1), Interval(1004, 1010.1), Interval(1011, 1013.1), Interval(1018, 1019.1), Interval(1035, 1038.1), Interval(1054, 1057.1), Interval(1073, 1080.1), Interval(1089, 1090.1), Interval(1092, 1093.1), Interval(1097, 1117.1), Interval(1125, 1133.1), Interval(1154, 1156.1), Interval(1160, 1161.1), Interval(1163, 1178.1), Interval(1180, 1188.1), Interval(1193, 1194.1), Interval(1209, 1211.1), Interval(1245, 1248.1), Interval(1270, 1276.1), Interval(1285, 1286.1), Interval(1295, 1299.1), Interval(1300, 1310.1), Interval(1311, 1317.1), Interval(1321, 1328.1), Interval(1369, 1370.1), Interval(1372, 1375.1), Interval(1386, 1389.1), Interval(1402, 1407.1), Interval(1408, 1411.1), Interval(1413, 1424.1), Interval(1425, 1432.1), Interval(1435, 1436.1), Interval(1450, 1453.1), Interval(1459, 1463.1), Interval(1467, 1468.1), Interval(1479, 1485.1), Interval(1486, 1490.1), Interval(1502, 1504.1), Interval(1505, 1507.1), Interval(1531, 1541.1), Interval(1547, 1561.1), Interval(1568, 1575.1), Interval(1576, 1592.1), Interval(1597, 1598.1), Interval(1604, 1626.1), Interval(1628, 1636.1), Interval(1643, 1644.1), Interval(1655, 1657.1), Interval(1681, 1687.1), Interval(1691, 1693.1), Interval(1698, 1699.1), Interval(1714, 1716.1), Interval(1723, 1725.1), Interval(1727, 1732.1), Interval(1737, 1740.1), Interval(1742, 1745.1), Interval(1756, 1758.1), Interval(1765, 1766.1), Interval(1775, 1776.1), Interval(1779, 1781.1), Interval(1786, 1789.1), Interval(1791, 1793.1), Interval(1794, 1796.1), Interval(1801, 1808.1), Interval(1816, 1817.1), Interval(1826, 1828.1), Interval(1830, 1831.1), Interval(1836, 1838.1), Interval(1856, 1857.1), Interval(1858, 1859.1), Interval(1860, 1864.1), Interval(1865, 1867.1), Interval(1871, 1881.1), Interval(1891, 1894.1), Interval(1915, 1920.1), Interval(1925, 1938.1), Interval(1955, 1957.1), Interval(1962, 1967.1), Interval(1969, 1973.1), Interval(1976, 1977.1), Interval(1978, 1981.1), Interval(1983, 1985.1), Interval(1990, 1994.1), Interval(1995, 1997.1), Interval(2001, 2003.1), Interval(2013, 2032.1), Interval(2035, 2037.1), Interval(2046, 2047.1), Interval(2048, 2050.1), Interval(2051, 2055.1), Interval(2056, 2057.1), Interval(2065, 2067.1), Interval(2069, 2070.1), Interval(2074, 2076.1), Interval(2079, 2082.1), Interval(2084, 2087.1), Interval(2089, 2095.1), Interval(2103, 2104.1), Interval(210 ...
#   '-': IntervalTree([Interval(0, 1.1), Interval(7, 10.1), Interval(16, 35.1), Interval(42, 48.1), Interval(61, 64.1), Interval(66, 74.1), Interval(84, 105.1), Interval(106, 110.1), Interval(135, 139.1), Interval(140, 141.1), Interval(150, 158.1), Interval(159, 161.1), Interval(162, 164.1), Interval(179, 183.1), Interval(191, 192.1), Interval(209, 212.1), Interval(214, 216.1), Interval(217, 218.1), Interval(226, 230.1), Interval(232, 234.1), Interval(236, 240.1), Interval(242, 253.1), Interval(269, 275.1), Interval(283, 287.1), Interval(289, 290.1), Interval(308, 312.1), Interval(334, 348.1), Interval(353, 354.1), Interval(377, 383.1), Interval(384, 395.1), Interval(406, 426.1), Interval(427, 435.1), Interval(446, 458.1), Interval(487, 490.1), Interval(498, 499.1), Interval(501, 507.1), Interval(510, 521.1), Interval(525, 536.1), Interval(537, 539.1), Interval(549, 552.1), Interval(553, 558.1), Interval(563, 573.1), Interval(576, 588.1), Interval(596, 600.1), Interval(604, 609.1), Interval(611, 623.1), Interval(633, 638.1), Interval(640, 655.1), Interval(658, 662.1), Interval(664, 667.1), Interval(669, 671.1), Interval(676, 683.1), Interval(693, 694.1), Interval(696, 698.1), Interval(699, 700.1), Interval(703, 715.1), Interval(720, 726.1), Interval(731, 736.1), Interval(751, 760.1), Interval(767, 769.1), Interval(774, 775.1), Interval(780, 786.1), Interval(806, 816.1), Interval(817, 826.1), Interval(838, 842.1), Interval(845, 853.1), Interval(857, 858.1), Interval(862, 872.1), Interval(882, 889.1), Interval(892, 903.1), Interval(910, 911.1), Interval(920, 925.1), Interval(944, 949.1), Interval(960, 964.1), Interval(969, 979.1), Interval(984, 992.1), Interval(1012, 1019.1), Interval(1023, 1026.1), Interval(1027, 1036.1), Interval(1037, 1047.1), Interval(1057, 1063.1), Interval(1066, 1070.1), Interval(1079, 1081.1), Interval(1084, 1090.1), Interval(1095, 1098.1), Interval(1110, 1111.1), Interval(1117, 1120.1), Interval(1122, 1125.1), Interval(1132, 1149.1), Interval(1151, 1154.1), Interval(1160, 1161.1), Interval(1188, 1191.1), Interval(1195, 1199.1), Interval(1202, 1204.1), Interval(1211, 1231.1), Interval(1233, 1239.1), Interval(1247, 1250.1), Interval(1251, 1256.1), Interval(1311, 1312.1), Interval(1328, 1330.1), Interval(1335, 1337.1), Interval(1343, 1345.1), Interval(1350, 1364.1), Interval(1365, 1368.1), Interval(1369, 1371.1), Interval(1379, 1380.1), Interval(1381, 1382.1), Interval(1384, 1385.1), Interval(1391, 1394.1), Interval(1396, 1397.1), Interval(1398, 1401.1), Interval(1405, 1406.1), Interval(1408, 1411.1), Interval(1422, 1423.1), Interval(1426, 1427.1), Interval(1433, 1434.1), Interval(1439, 1447.1), Interval(1452, 1454.1), Interval(1463, 1465.1), Interval(1467, 1468.1), Interval(1470, 1473.1), Interval(1474, 1475.1), Interval(1484, 1487.1), Interval(1489, 1498.1), Interval(1500, 1502.1), Interval(1504, 1505.1), Interval(1509, 1522.1), Interval(1534, 1537.1), Interval(1589, 1591.1), Interval(1619, 1620.1), Interval(1629, 1630.1), Interval(1638, 1643.1), Interval(1647, 1650.1), Interval(1651, 1654.1), Interval(1664, 1666.1), Interval(1667, 1669.1), Interval(1671, 1675.1), Interval(1676, 1679.1), Interval(1690, 1692.1), Interval(1693, 1697.1), Interval(1699, 1704.1), Interval(1706, 1707.1), Interval(1710, 1712.1), Interval(1716, 1719.1), Interval(1720, 1721.1), Interval(1745, 1747.1), Interval(1748, 1749.1), Interval(1764, 1765.1), Interval(1777, 1779.1), Interval(1792, 1793.1), Interval(1806, 1808.1), Interval(1810, 1812.1), Interval(1818, 1822.1), Interval(1823, 1826.1), Interval(1827, 1829.1), Interval(1831, 1832.1), Interval(1834, 1857.1), Interval(1880, 1881.1), Interval(1896, 1898.1), Interval(1910, 1914.1), Interval(1923, 1927.1), Interval(1929, 1930.1), Interval(1934, 1935.1), Interval(1936, 1946.1), Interval(1949, 1951.1), Interval(1952, 1954.1), Interval(1960, 1961.1), Interval(1973, 1975.1), Interval(1982, 1983.1), Interval(1986, 1990.1), Interval(1995, 1999.1), Interval(2030, 2048.1), Interval(2066, 2071 ...
#  'II': {'+': IntervalTree([Interval(0, 10.1), Interval(12, 17.1), Interval(19, 26.1), Interval(31, 36.1), Interval(43, 65.1), Interval(69, 72.1), Interval(82, 88.1), Interval(98, 102.1), Interval(104, 108.1), Interval(109, 115.1), Interval(117, 119.1), Interval(134, 140.1), Interval(147, 155.1), Interval(161, 171.1), Interval(179, 193.1), Interval(196, 212.1), Interval(241, 242.1), Interval(257, 262.1), Interval(264, 267.1), Interval(281, 282.1), Interval(286, 292.1), Interval(297, 301.1), Interval(302, 304.1), Interval(307, 316.1), Interval(319, 322.1), Interval(326, 329.1), Interval(333, 334.1), Interval(337, 342.1), Interval(375, 376.1), Interval(378, 383.1), Interval(386, 393.1), Interval(395, 396.1), Interval(402, 405.1), Interval(408, 409.1), Interval(410, 417.1), Interval(429, 433.1), Interval(436, 439.1), Interval(441, 447.1), Interval(455, 457.1), Interval(466, 467.1), Interval(476, 479.1), Interval(484, 491.1), Interval(495, 499.1), Interval(516, 531.1), Interval(535, 555.1), Interval(556, 565.1), Interval(573, 575.1), Interval(578, 579.1), Interval(580, 583.1), Interval(584, 590.1), Interval(592, 594.1), Interval(605, 608.1), Interval(609, 610.1), Interval(614, 615.1), Interval(627, 629.1), Interval(630, 632.1), Interval(634, 638.1), Interval(650, 655.1), Interval(656, 660.1), Interval(662, 665.1), Interval(667, 669.1), Interval(674, 694.1), Interval(702, 733.1), Interval(770, 773.1), Interval(774, 777.1), Interval(787, 790.1), Interval(799, 802.1), Interval(803, 804.1), Interval(807, 812.1), Interval(823, 831.1), Interval(840, 842.1), Interval(844, 846.1), Interval(848, 850.1), Interval(861, 863.1), Interval(868, 872.1), Interval(873, 891.1), Interval(893, 898.1), Interval(901, 907.1), Interval(909, 920.1), Interval(923, 926.1), Interval(928, 929.1), Interval(931, 937.1), Interval(938, 947.1), Interval(954, 965.1), Interval(968, 971.1), Interval(974, 976.1), Interval(979, 985.1), Interval(986, 996.1), Interval(1001, 1003.1), Interval(1007, 1010.1), Interval(1013, 1015.1), Interval(1019, 1024.1), Interval(1026, 1034.1), Interval(1046, 1049.1), Interval(1050, 1051.1), Interval(1055, 1056.1), Interval(1057, 1060.1), Interval(1062, 1064.1), Interval(1070, 1075.1), Interval(1083, 1084.1), Interval(1092, 1098.1), Interval(1106, 1107.1), Interval(1123, 1133.1), Interval(1136, 1153.1), Interval(1163, 1170.1), Interval(1197, 1231.1), Interval(1235, 1236.1), Interval(1242, 1243.1), Interval(1246, 1248.1), Interval(1255, 1263.1), Interval(1278, 1282.1), Interval(1285, 1287.1), Interval(1296, 1297.1), Interval(1298, 1300.1), Interval(1305, 1306.1), Interval(1310, 1324.1), Interval(1326, 1351.1), Interval(1361, 1362.1), Interval(1367, 1369.1), Interval(1370, 1372.1), Interval(1373, 1374.1), Interval(1375, 1376.1), Interval(1386, 1392.1), Interval(1398, 1410.1), Interval(1411, 1424.1), Interval(1431, 1432.1), Interval(1438, 1440.1), Interval(1445, 1447.1), Interval(1467, 1473.1), Interval(1478, 1479.1), Interval(1481, 1482.1), Interval(1504, 1510.1), Interval(1519, 1521.1), Interval(1525, 1526.1), Interval(1529, 1547.1), Interval(1548, 1549.1), Interval(1550, 1552.1), Interval(1556, 1558.1), Interval(1562, 1563.1), Interval(1568, 1570.1), Interval(1572, 1574.1), Interval(1586, 1588.1), Interval(1598, 1600.1), Interval(1601, 1606.1), Interval(1611, 1613.1), Interval(1625, 1627.1), Interval(1633, 1635.1), Interval(1636, 1639.1), Interval(1655, 1657.1), Interval(1663, 1668.1), Interval(1670, 1675.1), Interval(1676, 1678.1), Interval(1679, 1686.1), Interval(1706, 1712.1), Interval(1713, 1717.1), Interval(1722, 1734.1), Interval(1739, 1746.1), Interval(1756, 1779.1), Interval(1789, 1793.1), Interval(1797, 1802.1), Interval(1820, 1834.1), Interval(1836, 1841.1), Interval(1843, 1847.1), Interval(1851, 1856.1), Interval(1862, 1865.1), Interval(1866, 1868.1), Interval(1869, 1878.1), Interval(1890, 1892.1), Interval(1894, 1895.1), Interval(1896, 1898.1), Interval(1900, 1910.1), Interval(1923, 1929.1), Interval(1934, 1935.1), Interval(1948 ...
#   '-': IntervalTree([Interval(0, 1.1), Interval(9, 12.1), Interval(23, 24.1), Interval(25, 29.1), Interval(30, 32.1), Interval(34, 40.1), Interval(41, 47.1), Interval(53, 56.1), Interval(71, 80.1), Interval(82, 84.1), Interval(88, 99.1), Interval(103, 105.1), Interval(114, 122.1), Interval(123, 129.1), Interval(130, 135.1), Interval(146, 148.1), Interval(154, 157.1), Interval(171, 180.1), Interval(187, 190.1), Interval(192, 195.1), Interval(203, 204.1), Interval(205, 206.1), Interval(213, 221.1), Interval(222, 238.1), Interval(240, 256.1), Interval(266, 274.1), Interval(276, 288.1), Interval(289, 290.1), Interval(293, 295.1), Interval(296, 298.1), Interval(303, 306.1), Interval(309, 313.1), Interval(315, 319.1), Interval(321, 324.1), Interval(328, 333.1), Interval(341, 358.1), Interval(362, 369.1), Interval(382, 386.1), Interval(396, 400.1), Interval(406, 411.1), Interval(415, 416.1), Interval(417, 421.1), Interval(422, 430.1), Interval(433, 436.1), Interval(448, 454.1), Interval(456, 476.1), Interval(480, 485.1), Interval(488, 489.1), Interval(503, 507.1), Interval(508, 510.1), Interval(522, 524.1), Interval(530, 537.1), Interval(560, 561.1), Interval(567, 585.1), Interval(586, 587.1), Interval(590, 594.1), Interval(595, 603.1), Interval(607, 613.1), Interval(614, 625.1), Interval(637, 640.1), Interval(641, 652.1), Interval(656, 657.1), Interval(660, 662.1), Interval(669, 674.1), Interval(679, 681.1), Interval(691, 692.1), Interval(700, 702.1), Interval(734, 751.1), Interval(756, 766.1), Interval(779, 784.1), Interval(790, 792.1), Interval(793, 795.1), Interval(796, 799.1), Interval(801, 803.1), Interval(805, 807.1), Interval(812, 815.1), Interval(818, 823.1), Interval(831, 832.1), Interval(833, 836.1), Interval(837, 840.1), Interval(842, 844.1), Interval(845, 857.1), Interval(862, 867.1), Interval(875, 876.1), Interval(898, 902.1), Interval(907, 910.1), Interval(919, 923.1), Interval(926, 928.1), Interval(929, 931.1), Interval(946, 953.1), Interval(961, 963.1), Interval(965, 968.1), Interval(970, 973.1), Interval(976, 979.1), Interval(995, 997.1), Interval(999, 1002.1), Interval(1004, 1007.1), Interval(1010, 1013.1), Interval(1016, 1019.1), Interval(1023, 1025.1), Interval(1039, 1045.1), Interval(1048, 1050.1), Interval(1054, 1055.1), Interval(1059, 1061.1), Interval(1065, 1067.1), Interval(1071, 1072.1), Interval(1074, 1076.1), Interval(1088, 1089.1), Interval(1097, 1107.1), Interval(1108, 1111.1), Interval(1112, 1119.1), Interval(1121, 1124.1), Interval(1132, 1135.1), Interval(1139, 1143.1), Interval(1169, 1173.1), Interval(1174, 1180.1), Interval(1233, 1253.1), Interval(1262, 1267.1), Interval(1269, 1272.1), Interval(1273, 1277.1), Interval(1281, 1286.1), Interval(1288, 1294.1), Interval(1300, 1311.1), Interval(1319, 1320.1), Interval(1322, 1323.1), Interval(1333, 1334.1), Interval(1345, 1347.1), Interval(1349, 1356.1), Interval(1357, 1359.1), Interval(1361, 1362.1), Interval(1366, 1367.1), Interval(1368, 1375.1), Interval(1377, 1379.1), Interval(1380, 1386.1), Interval(1393, 1399.1), Interval(1404, 1406.1), Interval(1408, 1412.1), Interval(1414, 1416.1), Interval(1420, 1424.1), Interval(1425, 1438.1), Interval(1440, 1447.1), Interval(1459, 1462.1), Interval(1463, 1467.1), Interval(1472, 1474.1), Interval(1476, 1477.1), Interval(1484, 1486.1), Interval(1489, 1501.1), Interval(1510, 1518.1), Interval(1520, 1522.1), Interval(1523, 1526.1), Interval(1547, 1551.1), Interval(1555, 1557.1), Interval(1567, 1568.1), Interval(1570, 1572.1), Interval(1574, 1580.1), Interval(1581, 1585.1), Interval(1588, 1590.1), Interval(1593, 1596.1), Interval(1599, 1601.1), Interval(1604, 1611.1), Interval(1612, 1625.1), Interval(1627, 1628.1), Interval(1631, 1634.1), Interval(1639, 1641.1), Interval(1644, 1655.1), Interval(1656, 1658.1), Interval(1660, 1663.1), Interval(1667, 1670.1), Interval(1677, 1680.1), Interval(1686, 1696.1), Interval(1702, 1707.1), Interval(1718, 1720.1), Interval(1721, 1723.1), Interval(1733, 1739.1), Interval(1746, 1757 ...
#  'IV': {'+': IntervalTree([Interval(0, 15.1), Interval(21, 24.1), Interval(26, 33.1), Interval(36, 40.1), Interval(41, 42.1), Interval(58, 59.1), Interval(61, 68.1), Interval(76, 77.1), Interval(79, 81.1), Interval(92, 112.1), Interval(115, 119.1), Interval(126, 128.1), Interval(132, 139.1), Interval(143, 145.1), Interval(146, 147.1), Interval(152, 153.1), Interval(158, 170.1), Interval(175, 176.1), Interval(179, 221.1), Interval(240, 252.1), Interval(266, 273.1), Interval(274, 280.1), Interval(283, 288.1), Interval(307, 312.1), Interval(314, 315.1), Interval(322, 323.1), Interval(325, 335.1), Interval(339, 359.1), Interval(385, 389.1), Interval(390, 400.1), Interval(401, 406.1), Interval(410, 416.1), Interval(425, 430.1), Interval(443, 449.1), Interval(455, 458.1), Interval(503, 504.1), Interval(523, 527.1), Interval(532, 536.1), Interval(546, 547.1), Interval(548, 554.1), Interval(555, 556.1), Interval(558, 569.1), Interval(572, 584.1), Interval(593, 599.1), Interval(604, 621.1), Interval(624, 625.1), Interval(627, 634.1), Interval(649, 652.1), Interval(655, 659.1), Interval(665, 669.1), Interval(676, 680.1), Interval(683, 689.1), Interval(716, 718.1), Interval(735, 754.1), Interval(756, 763.1), Interval(771, 777.1), Interval(778, 785.1), Interval(787, 791.1), Interval(797, 807.1), Interval(828, 829.1), Interval(832, 834.1), Interval(842, 843.1), Interval(845, 849.1), Interval(855, 882.1), Interval(885, 913.1), Interval(919, 921.1), Interval(924, 940.1), Interval(959, 985.1), Interval(992, 1004.1), Interval(1010, 1020.1), Interval(1045, 1050.1), Interval(1056, 1058.1), Interval(1094, 1103.1), Interval(1104, 1106.1), Interval(1107, 1111.1), Interval(1115, 1116.1), Interval(1126, 1129.1), Interval(1141, 1143.1), Interval(1163, 1165.1), Interval(1170, 1202.1), Interval(1216, 1219.1), Interval(1226, 1228.1), Interval(1229, 1233.1), Interval(1247, 1250.1), Interval(1251, 1254.1), Interval(1256, 1260.1), Interval(1261, 1278.1), Interval(1289, 1297.1), Interval(1310, 1340.1), Interval(1341, 1345.1), Interval(1347, 1353.1), Interval(1356, 1357.1), Interval(1365, 1366.1), Interval(1386, 1400.1), Interval(1404, 1405.1), Interval(1406, 1409.1), Interval(1415, 1416.1), Interval(1420, 1422.1), Interval(1447, 1449.1), Interval(1457, 1460.1), Interval(1464, 1466.1), Interval(1485, 1490.1), Interval(1497, 1516.1), Interval(1523, 1527.1), Interval(1538, 1539.1), Interval(1548, 1568.1), Interval(1577, 1579.1), Interval(1597, 1609.1), Interval(1610, 1617.1), Interval(1620, 1638.1), Interval(1659, 1670.1), Interval(1672, 1678.1), Interval(1699, 1703.1), Interval(1707, 1709.1), Interval(1710, 1715.1), Interval(1720, 1724.1), Interval(1726, 1728.1), Interval(1745, 1752.1), Interval(1753, 1756.1), Interval(1768, 1770.1), Interval(1772, 1775.1), Interval(1821, 1823.1), Interval(1824, 1881.1), Interval(1902, 1922.1), Interval(1923, 1971.1), Interval(1973, 1976.1), Interval(1979, 2009.1), Interval(2037, 2045.1), Interval(2051, 2058.1), Interval(2066, 2072.1), Interval(2084, 2093.1), Interval(2094, 2095.1), Interval(2096, 2097.1), Interval(2114, 2116.1), Interval(2119, 2120.1), Interval(2122, 2127.1), Interval(2130, 2135.1), Interval(2136, 2147.1), Interval(2174, 2210.1), Interval(2222, 2236.1), Interval(2243, 2244.1), Interval(2245, 2253.1), Interval(2259, 2262.1), Interval(2314, 2315.1), Interval(2316, 2319.1), Interval(2324, 2327.1), Interval(2349, 2383.1), Interval(2384, 2397.1), Interval(2403, 2404.1), Interval(2432, 2437.1), Interval(2459, 2460.1), Interval(2464, 2466.1), Interval(2467, 2469.1), Interval(2470, 2472.1), Interval(2476, 2481.1), Interval(2482, 2485.1), Interval(2487, 2531.1), Interval(2533, 2534.1), Interval(2542, 2549.1), Interval(2551, 2558.1), Interval(2561, 2563.1), Interval(2568, 2573.1), Interval(2584, 2588.1), Interval(2592, 2598.1), Interval(2601, 2618.1), Interval(2619, 2626.1), Interval(2639, 2640.1), Interval(2641, 2651.1), Interval(2654, 2656.1), Interval(2664, 2666.1), Interval(2667, 2673.1), Interval(2676, 2679.1), In ...
#   '-': IntervalTree([Interval(8, 12.1), Interval(15, 21.1), Interval(24, 27.1), Interval(32, 49.1), Interval(53, 54.1), Interval(57, 59.1), Interval(64, 67.1), Interval(86, 91.1), Interval(108, 127.1), Interval(138, 148.1), Interval(152, 153.1), Interval(156, 158.1), Interval(225, 241.1), Interval(251, 265.1), Interval(272, 274.1), Interval(287, 299.1), Interval(311, 314.1), Interval(315, 324.1), Interval(325, 327.1), Interval(334, 338.1), Interval(343, 344.1), Interval(359, 377.1), Interval(379, 385.1), Interval(388, 391.1), Interval(393, 394.1), Interval(405, 411.1), Interval(415, 426.1), Interval(428, 441.1), Interval(451, 455.1), Interval(458, 482.1), Interval(498, 499.1), Interval(505, 524.1), Interval(527, 529.1), Interval(551, 553.1), Interval(558, 562.1), Interval(568, 571.1), Interval(580, 588.1), Interval(589, 593.1), Interval(595, 597.1), Interval(599, 604.1), Interval(605, 606.1), Interval(620, 621.1), Interval(624, 625.1), Interval(652, 655.1), Interval(668, 676.1), Interval(683, 684.1), Interval(688, 708.1), Interval(717, 732.1), Interval(736, 737.1), Interval(743, 744.1), Interval(753, 756.1), Interval(762, 769.1), Interval(770, 773.1), Interval(784, 785.1), Interval(786, 797.1), Interval(806, 825.1), Interval(828, 829.1), Interval(830, 832.1), Interval(835, 843.1), Interval(849, 855.1), Interval(867, 868.1), Interval(877, 879.1), Interval(926, 927.1), Interval(930, 936.1), Interval(940, 946.1), Interval(984, 991.1), Interval(1003, 1010.1), Interval(1027, 1031.1), Interval(1033, 1036.1), Interval(1038, 1042.1), Interval(1049, 1057.1), Interval(1058, 1068.1), Interval(1077, 1094.1), Interval(1103, 1105.1), Interval(1111, 1119.1), Interval(1121, 1126.1), Interval(1128, 1137.1), Interval(1141, 1143.1), Interval(1144, 1161.1), Interval(1174, 1175.1), Interval(1183, 1184.1), Interval(1192, 1194.1), Interval(1202, 1209.1), Interval(1219, 1222.1), Interval(1232, 1240.1), Interval(1241, 1247.1), Interval(1249, 1252.1), Interval(1253, 1256.1), Interval(1260, 1261.1), Interval(1297, 1310.1), Interval(1353, 1356.1), Interval(1357, 1360.1), Interval(1361, 1362.1), Interval(1373, 1374.1), Interval(1385, 1386.1), Interval(1388, 1389.1), Interval(1408, 1420.1), Interval(1423, 1447.1), Interval(1459, 1476.1), Interval(1487, 1489.1), Interval(1490, 1497.1), Interval(1508, 1509.1), Interval(1514, 1522.1), Interval(1527, 1537.1), Interval(1538, 1539.1), Interval(1545, 1596.1), Interval(1617, 1620.1), Interval(1628, 1630.1), Interval(1637, 1647.1), Interval(1651, 1652.1), Interval(1676, 1683.1), Interval(1689, 1690.1), Interval(1708, 1710.1), Interval(1723, 1725.1), Interval(1727, 1738.1), Interval(1740, 1746.1), Interval(1752, 1762.1), Interval(1775, 1782.1), Interval(1789, 1790.1), Interval(1802, 1804.1), Interval(1805, 1816.1), Interval(1817, 1821.1), Interval(1837, 1839.1), Interval(1900, 1902.1), Interval(1905, 1909.1), Interval(1970, 1973.1), Interval(2009, 2033.1), Interval(2034, 2036.1), Interval(2057, 2060.1), Interval(2083, 2084.1), Interval(2091, 2103.1), Interval(2104, 2114.1), Interval(2126, 2129.1), Interval(2138, 2141.1), Interval(2146, 2169.1), Interval(2174, 2175.1), Interval(2176, 2177.1), Interval(2216, 2217.1), Interval(2226, 2228.1), Interval(2237, 2243.1), Interval(2253, 2301.1), Interval(2303, 2317.1), Interval(2318, 2319.1), Interval(2327, 2332.1), Interval(2333, 2349.1), Interval(2388, 2390.1), Interval(2394, 2395.1), Interval(2396, 2413.1), Interval(2432, 2433.1), Interval(2436, 2464.1), Interval(2477, 2478.1), Interval(2494, 2496.1), Interval(2504, 2508.1), Interval(2546, 2547.1), Interval(2549, 2552.1), Interval(2559, 2560.1), Interval(2563, 2569.1), Interval(2578, 2582.1), Interval(2612, 2614.1), Interval(2626, 2629.1), Interval(2636, 2642.1), Interval(2650, 2666.1), Interval(2673, 2676.1), Interval(2678, 2708.1), Interval(2709, 2726.1), Interval(2734, 2736.1), Interval(2765, 2772.1), Interval(2777, 2783.1), Interval(2797, 2799.1), Interval(2800, 2802.1), Interval(2805, 2806.1), Interval(2814, 2820.1),  ...
#  'I': {'+': IntervalTree([Interval(11, 17.1), Interval(31, 33.1), Interval(43, 45.1), Interval(47, 55.1), Interval(71, 95.1), Interval(110, 121.1), Interval(127, 147.1), Interval(171, 176.1), Interval(178, 212.1), Interval(216, 217.1), Interval(218, 220.1), Interval(240, 246.1), Interval(252, 255.1), Interval(280, 287.1), Interval(291, 306.1), Interval(323, 331.1), Interval(332, 338.1), Interval(347, 358.1), Interval(364, 369.1), Interval(382, 389.1), Interval(398, 413.1), Interval(420, 424.1), Interval(443, 464.1), Interval(471, 474.1), Interval(477, 482.1), Interval(488, 497.1), Interval(506, 510.1), Interval(512, 513.1), Interval(514, 515.1), Interval(530, 543.1), Interval(550, 566.1), Interval(585, 586.1), Interval(613, 614.1), Interval(618, 623.1), Interval(636, 659.1), Interval(680, 684.1), Interval(688, 692.1), Interval(719, 732.1), Interval(740, 742.1), Interval(745, 749.1), Interval(754, 755.1), Interval(757, 761.1), Interval(763, 777.1), Interval(788, 789.1), Interval(803, 836.1), Interval(837, 842.1), Interval(846, 847.1), Interval(853, 873.1), Interval(882, 891.1), Interval(897, 912.1), Interval(916, 917.1), Interval(938, 948.1), Interval(979, 980.1), Interval(989, 993.1), Interval(996, 1011.1), Interval(1016, 1020.1), Interval(1034, 1051.1), Interval(1062, 1066.1), Interval(1068, 1076.1), Interval(1077, 1090.1), Interval(1107, 1116.1), Interval(1126, 1132.1), Interval(1156, 1163.1), Interval(1176, 1191.1), Interval(1193, 1259.1), Interval(1271, 1274.1), Interval(1278, 1280.1), Interval(1282, 1286.1), Interval(1287, 1288.1), Interval(1305, 1329.1), Interval(1332, 1342.1), Interval(1348, 1360.1), Interval(1365, 1377.1), Interval(1394, 1403.1), Interval(1405, 1414.1), Interval(1416, 1426.1), Interval(1436, 1442.1), Interval(1444, 1445.1), Interval(1446, 1470.1), Interval(1471, 1480.1), Interval(1483, 1491.1), Interval(1514, 1541.1), Interval(1543, 1557.1), Interval(1566, 1594.1), Interval(1601, 1607.1), Interval(1610, 1621.1), Interval(1629, 1645.1), Interval(1652, 1656.1), Interval(1667, 1670.1), Interval(1680, 1686.1), Interval(1691, 1694.1), Interval(1696, 1716.1), Interval(1721, 1741.1), Interval(1751, 1792.1), Interval(1793, 1797.1), Interval(1799, 1807.1), Interval(1808, 1814.1), Interval(1816, 1819.1), Interval(1822, 1826.1), Interval(1828, 1844.1), Interval(1845, 1851.1), Interval(1874, 1884.1), Interval(1895, 1946.1), Interval(1958, 1966.1), Interval(1967, 1975.1), Interval(1977, 1984.1), Interval(2019, 2020.1), Interval(2026, 2034.1), Interval(2046, 2049.1), Interval(2064, 2077.1), Interval(2078, 2086.1), Interval(2097, 2124.1), Interval(2128, 2146.1), Interval(2149, 2151.1), Interval(2160, 2210.1), Interval(2216, 2220.1), Interval(2242, 2248.1), Interval(2250, 2255.1), Interval(2269, 2270.1), Interval(2272, 2273.1), Interval(2279, 2282.1), Interval(2293, 2298.1), Interval(2300, 2303.1), Interval(2306, 2319.1), Interval(2327, 2331.1), Interval(2333, 2339.1), Interval(2342, 2351.1), Interval(2352, 2373.1), Interval(2402, 2411.1), Interval(2415, 2419.1), Interval(2434, 2436.1), Interval(2438, 2443.1), Interval(2445, 2449.1), Interval(2483, 2484.1), Interval(2485, 2507.1), Interval(2514, 2515.1), Interval(2524, 2525.1), Interval(2533, 2543.1), Interval(2544, 2547.1), Interval(2549, 2551.1), Interval(2552, 2564.1), Interval(2568, 2571.1), Interval(2599, 2603.1), Interval(2605, 2624.1), Interval(2629, 2635.1), Interval(2636, 2640.1), Interval(2642, 2646.1), Interval(2656, 2658.1), Interval(2666, 2667.1), Interval(2668, 2673.1), Interval(2678, 2679.1), Interval(2682, 2685.1), Interval(2688, 2690.1), Interval(2692, 2695.1), Interval(2697, 2703.1), Interval(2706, 2718.1), Interval(2727, 2728.1), Interval(2730, 2736.1), Interval(2739, 2741.1), Interval(2742, 2743.1), Interval(2744, 2746.1), Interval(2758, 2759.1), Interval(2760, 2762.1), Interval(2774, 2776.1), Interval(2786, 2788.1), Interval(2791, 2795.1), Interval(2796, 2798.1), Interval(2799, 2800.1), Interval(2802, 2821.1), Interval(2830, 2832.1), Interval(2835 ...
#   '-': IntervalTree([Interval(3, 11.1), Interval(17, 33.1), Interval(55, 65.1), Interval(84, 87.1), Interval(94, 112.1), Interval(115, 116.1), Interval(146, 155.1), Interval(160, 167.1), Interval(178, 179.1), Interval(182, 183.1), Interval(212, 216.1), Interval(219, 222.1), Interval(231, 240.1), Interval(248, 252.1), Interval(254, 260.1), Interval(263, 264.1), Interval(272, 273.1), Interval(286, 290.1), Interval(305, 315.1), Interval(316, 324.1), Interval(343, 349.1), Interval(357, 364.1), Interval(368, 382.1), Interval(388, 395.1), Interval(412, 419.1), Interval(462, 468.1), Interval(482, 488.1), Interval(496, 507.1), Interval(508, 522.1), Interval(526, 527.1), Interval(530, 531.1), Interval(536, 537.1), Interval(565, 567.1), Interval(572, 576.1), Interval(582, 584.1), Interval(585, 608.1), Interval(613, 637.1), Interval(645, 648.1), Interval(659, 675.1), Interval(682, 687.1), Interval(692, 699.1), Interval(700, 716.1), Interval(717, 720.1), Interval(731, 737.1), Interval(741, 746.1), Interval(748, 758.1), Interval(760, 762.1), Interval(774, 775.1), Interval(779, 780.1), Interval(796, 798.1), Interval(801, 802.1), Interval(806, 807.1), Interval(812, 813.1), Interval(841, 847.1), Interval(873, 883.1), Interval(889, 896.1), Interval(912, 927.1), Interval(942, 943.1), Interval(946, 947.1), Interval(948, 958.1), Interval(963, 977.1), Interval(979, 980.1), Interval(996, 997.1), Interval(1011, 1016.1), Interval(1019, 1034.1), Interval(1050, 1067.1), Interval(1089, 1096.1), Interval(1136, 1157.1), Interval(1162, 1176.1), Interval(1189, 1191.1), Interval(1215, 1220.1), Interval(1223, 1230.1), Interval(1251, 1252.1), Interval(1259, 1269.1), Interval(1278, 1280.1), Interval(1307, 1308.1), Interval(1341, 1345.1), Interval(1376, 1393.1), Interval(1413, 1416.1), Interval(1427, 1434.1), Interval(1442, 1444.1), Interval(1447, 1448.1), Interval(1451, 1454.1), Interval(1487, 1488.1), Interval(1490, 1515.1), Interval(1556, 1557.1), Interval(1575, 1576.1), Interval(1594, 1597.1), Interval(1600, 1602.1), Interval(1607, 1611.1), Interval(1621, 1629.1), Interval(1644, 1652.1), Interval(1655, 1668.1), Interval(1670, 1677.1), Interval(1686, 1694.1), Interval(1738, 1739.1), Interval(1740, 1752.1), Interval(1771, 1776.1), Interval(1779, 1783.1), Interval(1797, 1799.1), Interval(1813, 1817.1), Interval(1818, 1823.1), Interval(1832, 1833.1), Interval(1840, 1841.1), Interval(1851, 1853.1), Interval(1856, 1861.1), Interval(1862, 1873.1), Interval(1885, 1895.1), Interval(1911, 1914.1), Interval(1916, 1918.1), Interval(1945, 1959.1), Interval(1974, 1975.1), Interval(1988, 2011.1), Interval(2034, 2044.1), Interval(2049, 2051.1), Interval(2061, 2065.1), Interval(2068, 2071.1), Interval(2084, 2094.1), Interval(2107, 2109.1), Interval(2113, 2119.1), Interval(2149, 2152.1), Interval(2219, 2242.1), Interval(2243, 2244.1), Interval(2255, 2273.1), Interval(2281, 2292.1), Interval(2297, 2307.1), Interval(2315, 2316.1), Interval(2318, 2328.1), Interval(2330, 2333.1), Interval(2368, 2369.1), Interval(2370, 2371.1), Interval(2377, 2402.1), Interval(2410, 2411.1), Interval(2418, 2426.1), Interval(2429, 2434.1), Interval(2436, 2438.1), Interval(2440, 2442.1), Interval(2449, 2465.1), Interval(2468, 2486.1), Interval(2506, 2515.1), Interval(2546, 2549.1), Interval(2551, 2552.1), Interval(2571, 2577.1), Interval(2580, 2596.1), Interval(2605, 2606.1), Interval(2614, 2615.1), Interval(2620, 2621.1), Interval(2623, 2629.1), Interval(2645, 2658.1), Interval(2672, 2683.1), Interval(2684, 2685.1), Interval(2686, 2690.1), Interval(2698, 2699.1), Interval(2700, 2701.1), Interval(2703, 2704.1), Interval(2718, 2727.1), Interval(2735, 2743.1), Interval(2755, 2779.1), Interval(2780, 2791.1), Interval(2798, 2801.1), Interval(2820, 2834.1), Interval(2835, 2836.1), Interval(2837, 2839.1), Interval(2851, 2856.1), Interval(2858, 2860.1), Interval(2864, 2865.1), Interval(2870, 2877.1), Interval(2880, 2894.1), Interval(2895, 2901.1), Interval(2907, 2925.1), Interval(2940, 2942.1), Interval(29 ...
#  'MtDNA': {'+': IntervalTree([Interval(0, 14.1)]), '-': IntervalTree()},
#  'III': {'+': IntervalTree([Interval(3, 12.1), Interval(15, 18.1), Interval(41, 43.1), Interval(52, 54.1), Interval(57, 59.1), Interval(82, 84.1), Interval(87, 90.1), Interval(114, 119.1), Interval(120, 127.1), Interval(130, 138.1), Interval(156, 164.1), Interval(165, 167.1), Interval(168, 169.1), Interval(171, 175.1), Interval(178, 187.1), Interval(188, 290.1), Interval(292, 322.1), Interval(352, 356.1), Interval(365, 378.1), Interval(383, 385.1), Interval(402, 406.1), Interval(429, 432.1), Interval(434, 444.1), Interval(472, 483.1), Interval(488, 490.1), Interval(491, 503.1), Interval(535, 536.1), Interval(542, 547.1), Interval(557, 577.1), Interval(606, 607.1), Interval(640, 655.1), Interval(658, 663.1), Interval(675, 681.1), Interval(688, 716.1), Interval(725, 727.1), Interval(740, 743.1), Interval(761, 775.1), Interval(783, 787.1), Interval(794, 810.1), Interval(811, 814.1), Interval(816, 822.1), Interval(823, 827.1), Interval(832, 836.1), Interval(837, 838.1), Interval(842, 844.1), Interval(845, 851.1), Interval(854, 866.1), Interval(874, 876.1), Interval(879, 882.1), Interval(895, 901.1), Interval(911, 913.1), Interval(921, 922.1), Interval(938, 940.1), Interval(950, 958.1), Interval(962, 964.1), Interval(977, 989.1), Interval(991, 1007.1), Interval(1008, 1012.1), Interval(1020, 1022.1), Interval(1037, 1048.1), Interval(1052, 1053.1), Interval(1080, 1096.1), Interval(1099, 1100.1), Interval(1101, 1102.1), Interval(1103, 1112.1), Interval(1116, 1146.1), Interval(1152, 1185.1), Interval(1202, 1216.1), Interval(1218, 1219.1), Interval(1220, 1221.1), Interval(1225, 1227.1), Interval(1236, 1238.1), Interval(1239, 1246.1), Interval(1249, 1252.1), Interval(1255, 1257.1), Interval(1259, 1261.1), Interval(1263, 1266.1), Interval(1279, 1282.1), Interval(1285, 1288.1), Interval(1289, 1291.1), Interval(1295, 1300.1), Interval(1303, 1306.1), Interval(1309, 1312.1), Interval(1315, 1317.1), Interval(1325, 1331.1), Interval(1332, 1334.1), Interval(1342, 1345.1), Interval(1360, 1363.1), Interval(1370, 1372.1), Interval(1374, 1377.1), Interval(1381, 1382.1), Interval(1384, 1389.1), Interval(1399, 1407.1), Interval(1418, 1420.1), Interval(1424, 1425.1), Interval(1438, 1444.1), Interval(1458, 1467.1), Interval(1476, 1477.1), Interval(1496, 1510.1), Interval(1513, 1514.1), Interval(1524, 1526.1), Interval(1533, 1539.1), Interval(1540, 1544.1), Interval(1557, 1581.1), Interval(1604, 1607.1), Interval(1619, 1638.1), Interval(1641, 1642.1), Interval(1650, 1653.1), Interval(1686, 1688.1), Interval(1705, 1714.1), Interval(1717, 1718.1), Interval(1734, 1735.1), Interval(1758, 1760.1), Interval(1763, 1765.1), Interval(1766, 1767.1), Interval(1773, 1774.1), Interval(1777, 1779.1), Interval(1789, 1807.1), Interval(1809, 1810.1), Interval(1813, 1815.1), Interval(1822, 1823.1), Interval(1824, 1847.1), Interval(1849, 1853.1), Interval(1855, 1881.1), Interval(1887, 1890.1), Interval(1894, 1900.1), Interval(1904, 1940.1), Interval(1950, 1953.1), Interval(1964, 1965.1), Interval(1977, 1981.1), Interval(1985, 1988.1), Interval(1997, 2003.1), Interval(2006, 2010.1), Interval(2032, 2033.1), Interval(2060, 2061.1), Interval(2063, 2066.1), Interval(2071, 2073.1), Interval(2082, 2089.1), Interval(2092, 2100.1), Interval(2102, 2108.1), Interval(2111, 2113.1), Interval(2117, 2120.1), Interval(2124, 2207.1), Interval(2208, 2218.1), Interval(2219, 2223.1), Interval(2224, 2230.1), Interval(2233, 2237.1), Interval(2240, 2244.1), Interval(2246, 2250.1), Interval(2251, 2257.1), Interval(2263, 2265.1), Interval(2266, 2269.1), Interval(2272, 2290.1), Interval(2291, 2295.1), Interval(2308, 2311.1), Interval(2314, 2327.1), Interval(2331, 2367.1), Interval(2376, 2386.1), Interval(2395, 2396.1), Interval(2402, 2407.1), Interval(2418, 2430.1), Interval(2436, 2443.1), Interval(2446, 2449.1), Interval(2456, 2458.1), Interval(2461, 2467.1), Interval(2468, 2470.1), Interval(2473, 2495.1), Interval(2508, 2512.1), Interval(2529, 2547.1), Interval(2549, 2567.1), Interval(2579, 2581. ...
#   '-': IntervalTree([Interval(1, 4.1), Interval(12, 15.1), Interval(17, 24.1), Interval(35, 40.1), Interval(50, 51.1), Interval(59, 67.1), Interval(69, 88.1), Interval(89, 99.1), Interval(106, 108.1), Interval(109, 111.1), Interval(121, 123.1), Interval(130, 131.1), Interval(140, 157.1), Interval(163, 165.1), Interval(167, 172.1), Interval(174, 178.1), Interval(186, 189.1), Interval(191, 192.1), Interval(201, 208.1), Interval(223, 224.1), Interval(289, 299.1), Interval(335, 386.1), Interval(398, 401.1), Interval(408, 419.1), Interval(445, 446.1), Interval(453, 472.1), Interval(486, 487.1), Interval(492, 493.1), Interval(505, 517.1), Interval(518, 527.1), Interval(551, 552.1), Interval(576, 601.1), Interval(602, 606.1), Interval(607, 621.1), Interval(623, 641.1), Interval(662, 667.1), Interval(668, 669.1), Interval(680, 684.1), Interval(686, 697.1), Interval(706, 707.1), Interval(708, 709.1), Interval(710, 711.1), Interval(727, 753.1), Interval(755, 759.1), Interval(766, 767.1), Interval(774, 784.1), Interval(786, 794.1), Interval(821, 822.1), Interval(828, 833.1), Interval(835, 842.1), Interval(851, 854.1), Interval(867, 870.1), Interval(871, 874.1), Interval(877, 880.1), Interval(881, 887.1), Interval(889, 896.1), Interval(900, 911.1), Interval(913, 927.1), Interval(933, 939.1), Interval(940, 952.1), Interval(954, 955.1), Interval(960, 962.1), Interval(966, 981.1), Interval(1001, 1002.1), Interval(1003, 1004.1), Interval(1015, 1017.1), Interval(1023, 1025.1), Interval(1026, 1038.1), Interval(1045, 1054.1), Interval(1056, 1061.1), Interval(1062, 1077.1), Interval(1078, 1081.1), Interval(1101, 1102.1), Interval(1112, 1117.1), Interval(1125, 1137.1), Interval(1144, 1145.1), Interval(1159, 1160.1), Interval(1163, 1165.1), Interval(1175, 1177.1), Interval(1185, 1203.1), Interval(1216, 1223.1), Interval(1228, 1230.1), Interval(1233, 1234.1), Interval(1247, 1250.1), Interval(1253, 1255.1), Interval(1257, 1259.1), Interval(1261, 1263.1), Interval(1265, 1279.1), Interval(1282, 1285.1), Interval(1287, 1289.1), Interval(1292, 1299.1), Interval(1305, 1309.1), Interval(1311, 1316.1), Interval(1319, 1325.1), Interval(1333, 1343.1), Interval(1344, 1356.1), Interval(1357, 1360.1), Interval(1371, 1372.1), Interval(1375, 1381.1), Interval(1382, 1384.1), Interval(1386, 1389.1), Interval(1390, 1392.1), Interval(1406, 1428.1), Interval(1447, 1456.1), Interval(1467, 1518.1), Interval(1520, 1533.1), Interval(1535, 1536.1), Interval(1538, 1541.1), Interval(1544, 1559.1), Interval(1567, 1568.1), Interval(1575, 1576.1), Interval(1577, 1579.1), Interval(1583, 1602.1), Interval(1604, 1605.1), Interval(1606, 1615.1), Interval(1617, 1619.1), Interval(1630, 1635.1), Interval(1642, 1645.1), Interval(1648, 1649.1), Interval(1653, 1660.1), Interval(1662, 1669.1), Interval(1672, 1677.1), Interval(1683, 1696.1), Interval(1697, 1699.1), Interval(1701, 1706.1), Interval(1716, 1734.1), Interval(1743, 1745.1), Interval(1752, 1755.1), Interval(1757, 1759.1), Interval(1765, 1771.1), Interval(1772, 1779.1), Interval(1795, 1797.1), Interval(1807, 1819.1), Interval(1821, 1825.1), Interval(1878, 1879.1), Interval(1881, 1888.1), Interval(1891, 1894.1), Interval(1901, 1906.1), Interval(1939, 1944.1), Interval(1945, 1951.1), Interval(1952, 1962.1), Interval(1963, 1976.1), Interval(1980, 1985.1), Interval(2008, 2022.1), Interval(2032, 2033.1), Interval(2035, 2049.1), Interval(2053, 2055.1), Interval(2056, 2058.1), Interval(2060, 2061.1), Interval(2066, 2069.1), Interval(2073, 2077.1), Interval(2112, 2117.1), Interval(2139, 2140.1), Interval(2158, 2161.1), Interval(2204, 2205.1), Interval(2217, 2220.1), Interval(2222, 2224.1), Interval(2229, 2233.1), Interval(2238, 2241.1), Interval(2244, 2246.1), Interval(2249, 2252.1), Interval(2257, 2259.1), Interval(2260, 2262.1), Interval(2266, 2273.1), Interval(2276, 2277.1), Interval(2295, 2315.1), Interval(2326, 2332.1), Interval(2366, 2373.1), Interval(2384, 2387.1), Interval(2390, 2393.1), Interval(2394, 2402.1), Interval(2406, 2419 ...
